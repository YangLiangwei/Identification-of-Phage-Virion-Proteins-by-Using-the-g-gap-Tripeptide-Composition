# %%
#-*-coding:utf-8-*-
import itertools as iters
from time import time
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.cross_validation import KFold
from sklearn.feature_selection import f_classif
from sklearn.grid_search import GridSearchCV
from sklearn.svm import SVC
import matplotlib.pylab as plt
from sklearn.metrics import matthews_corrcoef

##计算二肽特征
def statisPsi(seqs, protein, gap):
    psi = np.zeros(len(seqs))
    loops = len(protein) - gap - 1
    for start in range(loops):
        dipeptide = protein[start] + protein[start + gap + 1]
        index = seqs.index(dipeptide)
        psi[index] += 1
    psi = np.array(psi)
    psi = psi / sum(psi)
    return psi

##计算三肽特征
def statisPsi_3(seqs,protein,gap):
    psi = np.zeros(len(seqs))
    loops = len(protein) - gap - 2
    for start in range(loops):
        dipeptide = protein[start:(start + 2)] + protein[start + 2 + gap]
        index = seqs.index(dipeptide)
        psi[index] += 1
    psi = np.array(psi)
    psi = psi / sum(psi)
    return psi

# get gap dipeptide features psi matrix",
def all_psi(dataset,gap):
    gap_psi = np.zeros((len(dataset), len(DIPEPTIDE)))
    for idx in range(len(dataset)):
        gap_psi[idx] = statisPsi(DIPEPTIDE, dataset[idx], gap)
    return gap_psi

#输入核函数名称和参数gamma值，返回SVM训练十折交叉验证的准确率
def SVM_10fold(data,label):
    ##数据归一化（按列处理，必须做）
    scaler = preprocessing.StandardScaler().fit(data)
    data = scaler.transform(data)
    kf = KFold(data.shape[0],n_folds=10,shuffle = True)  #固定随机数可固定分组
    precision_average = 0.0
    TPCount = 0
    TNCount = 0
    train = []
    test = []
    test_true = []

    C_range = np.logspace(15, 5, 11, base=2)
    gamma_range = np.logspace(-15, -25, 11, base=2)
    param_grid = dict(gamma=gamma_range, C=C_range)
    grid = GridSearchCV(SVC(kernel='rbf'), param_grid=param_grid, cv=5)  # 基于交叉验证的网格搜索

    for train_index, test_index in kf:
        grid = grid.fit(data[train_index],label[train_index])
        clf = SVC(C = grid.best_params_['C'],gamma=grid.best_params_['gamma'])
        clf.fit(data[train_index],label[train_index])
        pred_train = clf.predict(data[train_index]).tolist()
        pred_test = clf.predict(data[test_index]).tolist()

        train.append(pred_train)
        test = test + pred_test
        test_true = test_true + label[test_index].tolist()

        testLabel = label[test_index]

        # print(metrics.confusion_matrix(pred_train,trainLabel))
        TP = 0
        TN = 0
        #同时输出svm的结果
        #查看测试集的结果
        for i in range(len(pred_test)):
            if pred_test[i] == 1 and (testLabel[i] == 1):
                TP = TP + 1
            elif pred_test[i] == 0 and (testLabel[i] == 0):
                TN = TN + 1
        TPCount = TPCount + TP
        TNCount = TNCount + TN

        precision = (TP + TN) * 1.0 / len(testLabel)
        precision_average = precision_average + precision


    precision_average = precision_average / 10
    positiveReca1 = TPCount * 1.0 / 99
    negtiveReca1 = TNCount * 1.0 / 208
    MCC = matthews_corrcoef(test_true,test)


    print (u'SVM的测试集结果：')
    print (TPCount,TNCount)
    print (u'准确率为' + str(precision_average))
    print (u'正类召回率为' + str(positiveReca1))
    print (u'负类召回率为' + str(negtiveReca1))
    print(u'MCC为' + str(matthews_corrcoef(test_true,test)))
   


    # ##保存最优模型的训练、测试集结果
    # with open('C:\\Users\Administrator\Desktop\data\\result\\result_4gapTC_svm_train.txt','w') as file:
    #     for i in train:
    #         file.write(str(i) + '\n')
    # with open('C:\\Users\Administrator\Desktop\data\\result\\result_4gapTC_svm_test.txt','w') as file:
    #     for i in test:
    #         file.write(str(i) + '\n')


    return precision_average,positiveReca1,negtiveReca1,MCC

if(__name__=='__main__'):
    # t0 = time()
    path = r''
    with open('virion.txt', "r") as file:
        train_tdata = [line.strip() for line in file if '>' != line[0]]
    with open( 'non-virion.txt', "r") as file:
        train_fdata = [line.strip() for line in file if '>' != line[0]]

    SAA = ('ACDEFGHIKLMNPQRSTVWY')
    DIPEPTIDE = []

    for dipeptide in iters.product(SAA, repeat=2):
        DIPEPTIDE.append(''.join(dipeptide))

    label = pd.Series([1 for i in range(len(train_tdata))]+ [0 for i in range(len(train_fdata))])
    label = label.as_matrix()

    ##将序列处理为特征向量
    gap=1
    gap_T = all_psi(train_tdata,gap)
    gap_F = all_psi(train_fdata,gap)

    dataAll = np.row_stack((gap_T, gap_F))  # 矩阵按行合并
    # print(data.shape)
    ##将特征结果保存，方便下次直接读取
    # np.savetxt('E:\Python Program\Protein\data\gapAll\\virion_gap0_dipe2.csv', data, delimiter=',')
    ##直接读入特征数据
    # dataAll = pd.read_csv(path = '\\virion_gap0_dipe2.csv',header=None).as_matrix()


    print(dataAll.shape)
    ##计算F值（ANOVA）
    f = f_classif(dataAll, label)[0]

    ##因为三肽特征较为稀疏，会有一些全为nan的列，要对这些列进行处理
    a = np.array(f)
    nan_count = np.sum(a != a)
    print(nan_count)
    ##将nan替换为0
    f1 = np.nan_to_num(a)
    ##将F值从大到小排序，获得相应的位置序号
    f_order = np.argsort(f1).tolist()[::-1]
    print(f_order)

    #选取所需的特征维度，构造模型
    data = dataAll[:,f_order[0:159]]
    acc = []
    pr = []
    nr = []
    MCC = []
    for cishu in range(200):
        presion,positiveRecall,negtiveRecall,matthews = SVM_10fold(data,label)
        acc.append(presion)
        pr.append(positiveRecall)
        nr.append(negtiveRecall)
        MCC.append(matthews)
        print(cishu)


#     ###为了选取最优特征子集，一般需要遍历，结果运行、保存、展示如下
#     p = []
#     for i in range(1,dataAll.shape[1]+1):
#         data = dataAll[:, f_order[0:i]]
#         print(data.shape)
#         presion, positiveRecall, negtiveRecall = SVM_10fold(data, label)
#         p.append(presion)
#     # print(SVM_10fold(data,label))
#     np.savetxt(str(gap)+'statisPsi.csv',p,delimiter=',')
#     plt.plot(range(len(p)),p)
#     plt.savefig(str(gap)+'statisPsi.pdf')
#     plt.show()
#     plt.close()
# Out:
# (307, 400)
# 0
# [5, 16, 12, 316, 300, 69, 340, 335, 356, 100, 169, 105, 163, 305, 345, 347, 63, 68, 325, 85, 113, 166, 66, 171, 183, 143, 179, 174, 48, 397, 240, 117, 383, 306, 317, 61, 357, 145, 49, 15, 188, 62, 83, 162, 167, 28, 283, 222, 228, 64, 170, 276, 43, 17, 157, 288, 237, 337, 336, 181, 349, 79, 236, 116, 6, 13, 82, 194, 203, 137, 331, 44, 107, 67, 148, 11, 262, 294, 320, 386, 399, 363, 77, 27, 339, 156, 56, 74, 172, 140, 128, 154, 368, 268, 1, 7, 270, 286, 126, 197, 131, 178, 248, 199, 329, 52, 176, 388, 161, 88, 257, 57, 328, 0, 71, 241, 31, 139, 332, 65, 220, 385, 104, 146, 8, 355, 229, 301, 396, 122, 291, 23, 292, 376, 362, 334, 217, 214, 173, 269, 25, 182, 109, 189, 136, 210, 218, 168, 394, 303, 274, 201, 380, 264, 398, 297, 129, 120, 158, 54, 232, 223, 4, 72, 123, 351, 280, 200, 165, 365, 258, 361, 38, 132, 287, 370, 206, 389, 254, 234, 70, 86, 124, 346, 3, 375, 133, 333, 205, 10, 213, 22, 318, 33, 101, 125, 233, 282, 338, 55, 41, 314, 390, 184, 235, 26, 138, 21, 152, 215, 387, 242, 348, 279, 312, 310, 18, 289, 330, 344, 121, 84, 267, 251, 327, 36, 367, 249, 307, 134, 14, 37, 377, 42, 358, 35, 263, 208, 30, 180, 354, 160, 187, 302, 47, 53, 284, 352, 76, 90, 343, 373, 216, 89, 78, 111, 135, 360, 192, 151, 92, 185, 39, 142, 247, 326, 315, 369, 102, 285, 207, 164, 364, 225, 195, 103, 96, 73, 211, 342, 149, 374, 93, 118, 273, 266, 252, 186, 350, 226, 221, 115, 159, 175, 311, 298, 321, 219, 395, 99, 322, 40, 308, 296, 80, 95, 275, 261, 141, 212, 114, 372, 29, 309, 190, 277, 59, 51, 87, 119, 130, 144, 58, 20, 384, 60, 304, 391, 224, 238, 110, 293, 290, 371, 191, 97, 324, 259, 271, 359, 243, 193, 50, 379, 75, 94, 250, 106, 32, 319, 147, 112, 299, 108, 127, 313, 255, 341, 393, 91, 323, 260, 244, 196, 227, 265, 239, 230, 256, 353, 202, 24, 272, 198, 150, 231, 153, 245, 378, 295, 278, 381, 9, 382, 81, 392, 98, 281, 155, 366, 45, 177, 253, 46, 246, 204, 2, 19, 34, 209]
# SVM的测试集结果：
# 72 182
# 准确率为0.8272043010752688
# 正类召回率为0.7272727272727273
# 负类召回率为0.875
# MCC为0.603887835368
# 0
# SVM的测试集结果：
# 71 186
# 准确率为0.8369892473118281
# 正类召回率为0.7171717171717171
# 负类召回率为0.8942307692307693
# MCC为0.621910808035
# 1
# SVM的测试集结果：
# 76 183
# 准确率为0.8440860215053764
# 正类召回率为0.7676767676767676
# 负类召回率为0.8798076923076923
# MCC为0.644146004432
# 2
# SVM的测试集结果：
# 72 183
# 准确率为0.830967741935484
# 正类召回率为0.7272727272727273
# 负类召回率为0.8798076923076923
# MCC为0.610379551683
# 3
# SVM的测试集结果：
# 73 181
# 准确率为0.8275268817204301
# 正类召回率为0.7373737373737373
# 负类召回率为0.8701923076923077
# MCC为0.605979017423
# 4
# SVM的测试集结果：
# 71 180
# 准确率为0.8168817204301076
# 正类召回率为0.7171717171717171
# 负类召回率为0.8653846153846154
# MCC为0.582556332556
# 5
# SVM的测试集结果：
# 70 182
# 准确率为0.8212903225806452
# 正类召回率为0.7070707070707071
# 负类召回率为0.875
# MCC为0.586878452389
# 6
# SVM的测试集结果：
# 73 181
# 准确率为0.8278494623655914
# 正类召回率为0.7373737373737373
# 负类召回率为0.8701923076923077
# MCC为0.605979017423
# 7
# SVM的测试集结果：
# 71 181
# 准确率为0.8206451612903226
# 正类召回率为0.7171717171717171
# 负类召回率为0.8701923076923077
# MCC为0.588939152457
# 8
# SVM的测试集结果：
# 69 184
# 准确率为0.8245161290322581
# 正类召回率为0.696969696969697
# 负类召回率为0.8846153846153846
# MCC为0.591580924307
# 9
# SVM的测试集结果：
# 71 184
# 准确率为0.8304301075268817
# 正类召回率为0.7171717171717171
# 负类召回率为0.8846153846153846
# MCC为0.608502556069
# 10
# SVM的测试集结果：
# 72 184
# 准确率为0.8343010752688172
# 正类召回率为0.7272727272727273
# 负类召回率为0.8846153846153846
# MCC为0.61694214084
# 11
# SVM的测试集结果：
# 69 186
# 准确率为0.8305376344086021
# 正类召回率为0.696969696969697
# 负类召回率为0.8942307692307693
# MCC为0.605112968878
# 12
# SVM的测试集结果：
# 69 188
# 准确率为0.8373118279569892
# 正类召回率为0.696969696969697
# 负类召回率为0.9038461538461539
# MCC为0.618966858961
# 13
# SVM的测试集结果：
# 73 184
# 准确率为0.8372043010752689
# 正类召回率为0.7373737373737373
# 负类召回率为0.8846153846153846
# MCC为0.625369274294
# 14
# SVM的测试集结果：
# 76 186
# 准确率为0.8535483870967744
# 正类召回率为0.7676767676767676
# 负类召回率为0.8942307692307693
# MCC为0.66368256701
# 15
# SVM的测试集结果：
# 67 183
# 准确率为0.814516129032258
# 正类召回率为0.6767676767676768
# 负类召回率为0.8798076923076923
# MCC为0.567884616416
# 16
# SVM的测试集结果：
# 75 184
# 准确率为0.8436559139784945
# 正类召回率为0.7575757575757576
# 负类召回率为0.8846153846153846
# MCC为0.642191142191
# 17
# SVM的测试集结果：
# 72 187
# 准确率为0.8433333333333334
# 正类召回率为0.7272727272727273
# 负类召回率为0.8990384615384616
# MCC为0.637075749899
# 18
# SVM的测试集结果：
# 73 181
# 准确率为0.8276344086021507
# 正类召回率为0.7373737373737373
# 负类召回率为0.8701923076923077
# MCC为0.605979017423
# 19
# SVM的测试集结果：
# 76 185
# 准确率为0.8506451612903227
# 正类召回率为0.7676767676767676
# 负类召回率为0.8894230769230769
# MCC为0.6570998446
# 20
# SVM的测试集结果：
# 72 182
# 准确率为0.8273118279569893
# 正类召回率为0.7272727272727273
# 负类召回率为0.875
# MCC为0.603887835368
# 21
# SVM的测试集结果：
# 73 186
# 准确率为0.8434408602150537
# 正类召回率为0.7373737373737373
# 负类召回率为0.8942307692307693
# MCC为0.638652698856
# 22
# SVM的测试集结果：
# 76 186
# 准确率为0.8534408602150538
# 正类召回率为0.7676767676767676
# 负类召回率为0.8942307692307693
# MCC为0.66368256701
# 23
# SVM的测试集结果：
# 76 182
# 准确率为0.8403225806451614
# 正类召回率为0.7676767676767676
# 负类召回率为0.875
# MCC为0.637771119698
# 24
# SVM的测试集结果：
# 72 182
# 准确率为0.8272043010752688
# 正类召回率为0.7272727272727273
# 负类召回率为0.875
# MCC为0.603887835368
# 25
# SVM的测试集结果：
# 74 184
# 准确率为0.8397849462365592
# 正类召回率为0.7474747474747475
# 负类召回率为0.8846153846153846
# MCC为0.633785201189
# 26
# SVM的测试集结果：
# 77 182
# 准确率为0.8434408602150537
# 正类召回率为0.7777777777777778
# 负类召回率为0.875
# MCC为0.646220796451
# 27
# SVM的测试集结果：
# 73 183
# 准确率为0.8344086021505376
# 正类召回率为0.7373737373737373
# 负类召回率为0.8798076923076923
# MCC为0.618836518278
# 28
# SVM的测试集结果：
# 73 185
# 准确率为0.8404301075268817
# 正类召回率为0.7373737373737373
# 负类召回率为0.8894230769230769
# MCC为0.631973985065
# 29
# SVM的测试集结果：
# 73 179
# 准确率为0.8210752688172043
# 正类召回率为0.7373737373737373
# 负类召回率为0.8605769230769231
# MCC为0.593386413544
# 30
# SVM的测试集结果：
# 76 187
# 准确率为0.8567741935483871
# 正类召回率为0.7676767676767676
# 负类召回率为0.8990384615384616
# MCC为0.670338442129
# 31
# SVM的测试集结果：
# 73 184
# 准确率为0.8368817204301076
# 正类召回率为0.7373737373737373
# 负类召回率为0.8846153846153846
# MCC为0.625369274294
# 32
# SVM的测试集结果：
# 70 184
# 准确率为0.8276344086021504
# 正类召回率为0.7070707070707071
# 负类召回率为0.8846153846153846
# MCC为0.600049249681
# 33
# SVM的测试集结果：
# 75 183
# 准确率为0.8405376344086022
# 正类召回率为0.7575757575757576
# 负类召回率为0.8798076923076923
# MCC为0.635718535982
# 34
# SVM的测试集结果：
# 74 184
# 准确率为0.8406451612903225
# 正类召回率为0.7474747474747475
# 负类召回率为0.8846153846153846
# MCC为0.633785201189
# 35
# SVM的测试集结果：
# 75 182
# 准确率为0.836774193548387
# 正类召回率为0.7575757575757576
# 负类召回率为0.875
# MCC为0.629314171884
# 36
# SVM的测试集结果：
# 64 182
# 准确率为0.8013978494623656
# 正类召回率为0.6464646464646465
# 负类召回率为0.875
# MCC为0.535455043033
# 37
# SVM的测试集结果：
# 71 187
# 准确率为0.8405376344086021
# 正类召回率为0.7171717171717171
# 负类召回率为0.8990384615384616
# MCC为0.628731166364
# 38
# SVM的测试集结果：
# 73 185
# 准确率为0.8407526881720431
# 正类召回率为0.7373737373737373
# 负类召回率为0.8894230769230769
# MCC为0.631973985065
# 39
# SVM的测试集结果：
# 69 188
# 准确率为0.8370967741935484
# 正类召回率为0.696969696969697
# 负类召回率为0.9038461538461539
# MCC为0.618966858961
# 40
# SVM的测试集结果：
# 68 185
# 准确率为0.8235483870967741
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 41
# SVM的测试集结果：
# 73 180
# 准确率为0.8241935483870968
# 正类召回率为0.7373737373737373
# 负类召回率为0.8653846153846154
# MCC为0.599650506788
# 42
# SVM的测试集结果：
# 70 182
# 准确率为0.8203225806451613
# 正类召回率为0.7070707070707071
# 负类召回率为0.875
# MCC为0.586878452389
# 43
# SVM的测试集结果：
# 73 184
# 准确率为0.8368817204301076
# 正类召回率为0.7373737373737373
# 负类召回率为0.8846153846153846
# MCC为0.625369274294
# 44
# SVM的测试集结果：
# 72 184
# 准确率为0.8336559139784947
# 正类召回率为0.7272727272727273
# 负类召回率为0.8846153846153846
# MCC为0.61694214084
# 45
# SVM的测试集结果：
# 70 182
# 准确率为0.8205376344086022
# 正类召回率为0.7070707070707071
# 负类召回率为0.875
# MCC为0.586878452389
# 46
# SVM的测试集结果：
# 71 183
# 准确率为0.827956989247312
# 正类召回率为0.7171717171717171
# 负类召回率为0.8798076923076923
# MCC为0.601910296614
# 47
# SVM的测试集结果：
# 73 179
# 准确率为0.8209677419354838
# 正类召回率为0.7373737373737373
# 负类召回率为0.8605769230769231
# MCC为0.593386413544
# 48
# SVM的测试集结果：
# 66 186
# 准确率为0.8207526881720432
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 49
# SVM的测试集结果：
# 76 185
# 准确率为0.850215053763441
# 正类召回率为0.7676767676767676
# 负类召回率为0.8894230769230769
# MCC为0.6570998446
# 50
# SVM的测试集结果：
# 71 184
# 准确率为0.8298924731182795
# 正类召回率为0.7171717171717171
# 负类召回率为0.8846153846153846
# MCC为0.608502556069
# 51
# SVM的测试集结果：
# 76 185
# 准确率为0.8498924731182795
# 正类召回率为0.7676767676767676
# 负类召回率为0.8894230769230769
# MCC为0.6570998446
# 52
# SVM的测试集结果：
# 77 181
# 准确率为0.8404301075268817
# 正类召回率为0.7777777777777778
# 负类召回率为0.8701923076923077
# MCC为0.639940406206
# 53
# SVM的测试集结果：
# 74 184
# 准确率为0.8405376344086021
# 正类召回率为0.7474747474747475
# 负类召回率为0.8846153846153846
# MCC为0.633785201189
# 54
# SVM的测试集结果：
# 75 185
# 准确率为0.8468817204301076
# 正类召回率为0.7575757575757576
# 负类召回率为0.8894230769230769
# MCC为0.6487338841
# 55
# SVM的测试集结果：
# 71 183
# 准确率为0.8270967741935484
# 正类召回率为0.7171717171717171
# 负类召回率为0.8798076923076923
# MCC为0.601910296614
# 56
# SVM的测试集结果：
# 69 183
# 准确率为0.8206451612903225
# 正类召回率为0.696969696969697
# 负类召回率为0.8798076923076923
# MCC为0.584929820951
# 57
# SVM的测试集结果：
# 75 183
# 准确率为0.8401075268817205
# 正类召回率为0.7575757575757576
# 负类召回率为0.8798076923076923
# MCC为0.635718535982
# 58
# SVM的测试集结果：
# 71 185
# 准确率为0.8338709677419354
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 59
# SVM的测试集结果：
# 70 181
# 准确率为0.8181720430107529
# 正类召回率为0.7070707070707071
# 负类召回率为0.8701923076923077
# MCC为0.58040010646
# 60
# SVM的测试集结果：
# 72 182
# 准确率为0.8272043010752688
# 正类召回率为0.7272727272727273
# 负类召回率为0.875
# MCC为0.603887835368
# 61
# SVM的测试集结果：
# 77 183
# 准确率为0.846774193548387
# 正类召回率为0.7777777777777778
# 负类召回率为0.8798076923076923
# MCC为0.652566021749
# 62
# SVM的测试集结果：
# 70 182
# 准确率为0.8205376344086022
# 正类召回率为0.7070707070707071
# 负类召回率为0.875
# MCC为0.586878452389
# 63
# SVM的测试集结果：
# 70 181
# 准确率为0.8172043010752688
# 正类召回率为0.7070707070707071
# 负类召回率为0.8701923076923077
# MCC为0.58040010646
# 64
# SVM的测试集结果：
# 74 184
# 准确率为0.8406451612903227
# 正类召回率为0.7474747474747475
# 负类召回率为0.8846153846153846
# MCC为0.633785201189
# 65
# SVM的测试集结果：
# 72 183
# 准确率为0.8306451612903227
# 正类召回率为0.7272727272727273
# 负类召回率为0.8798076923076923
# MCC为0.610379551683
# 66
# SVM的测试集结果：
# 70 183
# 准确率为0.8240860215053765
# 正类召回率为0.7070707070707071
# 负类召回率为0.8798076923076923
# MCC为0.593427484675
# 67
# SVM的测试集结果：
# 72 188
# 准确率为0.8466666666666667
# 正类召回率为0.7272727272727273
# 负类召回率为0.9038461538461539
# MCC为0.643942803851
# 68
# SVM的测试集结果：
# 71 185
# 准确率为0.8343010752688172
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 69
# SVM的测试集结果：
# 73 183
# 准确率为0.8339784946236559
# 正类召回率为0.7373737373737373
# 负类召回率为0.8798076923076923
# MCC为0.618836518278
# 70
# SVM的测试集结果：
# 73 186
# 准确率为0.8436559139784947
# 正类召回率为0.7373737373737373
# 负类召回率为0.8942307692307693
# MCC为0.638652698856
# 71
# SVM的测试集结果：
# 77 184
# 准确率为0.8504301075268816
# 正类召回率为0.7777777777777778
# 负类召回率为0.8846153846153846
# MCC为0.658977836979
# 72
# SVM的测试集结果：
# 73 187
# 准确率为0.8464516129032258
# 正类召回率为0.7373737373737373
# 负类召回率为0.8990384615384616
# MCC为0.645407535873
# 73
# SVM的测试集结果：
# 70 184
# 准确率为0.8278494623655914
# 正类召回率为0.7070707070707071
# 负类召回率为0.8846153846153846
# MCC为0.600049249681
# 74
# SVM的测试集结果：
# 78 186
# 准确率为0.8596774193548387
# 正类召回率为0.7878787878787878
# 负类召回率为0.8942307692307693
# MCC为0.680327813821
# 75
# SVM的测试集结果：
# 73 183
# 准确率为0.8335483870967743
# 正类召回率为0.7373737373737373
# 负类召回率为0.8798076923076923
# MCC为0.618836518278
# 76
# SVM的测试集结果：
# 73 187
# 准确率为0.8469892473118279
# 正类召回率为0.7373737373737373
# 负类召回率为0.8990384615384616
# MCC为0.645407535873
# 77
# SVM的测试集结果：
# 73 182
# 准确率为0.8310752688172045
# 正类召回率为0.7373737373737373
# 负类召回率为0.875
# MCC为0.612373737374
# 78
# SVM的测试集结果：
# 75 182
# 准确率为0.8366666666666667
# 正类召回率为0.7575757575757576
# 负类召回率为0.875
# MCC为0.629314171884
# 79
# SVM的测试集结果：
# 71 186
# 准确率为0.8376344086021505
# 正类召回率为0.7171717171717171
# 负类召回率为0.8942307692307693
# MCC为0.621910808035
# 80
# SVM的测试集结果：
# 71 183
# 准确率为0.8276344086021504
# 正类召回率为0.7171717171717171
# 负类召回率为0.8798076923076923
# MCC为0.601910296614
# 81
# SVM的测试集结果：
# 73 181
# 准确率为0.8275268817204301
# 正类召回率为0.7373737373737373
# 负类召回率为0.8701923076923077
# MCC为0.605979017423
# 82
# SVM的测试集结果：
# 66 184
# 准确率为0.813978494623656
# 正类召回率为0.6666666666666666
# 负类召回率为0.8846153846153846
# MCC为0.566072420238
# 83
# SVM的测试集结果：
# 72 181
# 准确率为0.8237634408602151
# 正类召回率为0.7272727272727273
# 负类召回率为0.8701923076923077
# MCC为0.597465034965
# 84
# SVM的测试集结果：
# 73 182
# 准确率为0.8297849462365592
# 正类召回率为0.7373737373737373
# 负类召回率为0.875
# MCC为0.612373737374
# 85
# SVM的测试集结果：
# 71 185
# 准确率为0.8339784946236559
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 86
# SVM的测试集结果：
# 73 184
# 准确率为0.8369892473118281
# 正类召回率为0.7373737373737373
# 负类召回率为0.8846153846153846
# MCC为0.625369274294
# 87
# SVM的测试集结果：
# 71 184
# 准确率为0.8300000000000001
# 正类召回率为0.7171717171717171
# 负类召回率为0.8846153846153846
# MCC为0.608502556069
# 88
# SVM的测试集结果：
# 71 182
# 准确率为0.8244086021505377
# 正类召回率为0.7171717171717171
# 负类召回率为0.875
# MCC为0.595389829071
# 89
# SVM的测试集结果：
# 75 183
# 准确率为0.8402150537634409
# 正类召回率为0.7575757575757576
# 负类召回率为0.8798076923076923
# MCC为0.635718535982
# 90
# SVM的测试集结果：
# 72 185
# 准确率为0.8372043010752688
# 正类召回率为0.7272727272727273
# 负类召回率为0.8894230769230769
# MCC为0.623577627463
# 91
# SVM的测试集结果：
# 77 183
# 准确率为0.8466666666666667
# 正类召回率为0.7777777777777778
# 负类召回率为0.8798076923076923
# MCC为0.652566021749
# 92
# SVM的测试集结果：
# 74 185
# 准确率为0.8435483870967742
# 正类召回率为0.7474747474747475
# 负类召回率为0.8894230769230769
# MCC为0.640358996906
# 93
# SVM的测试集结果：
# 72 186
# 准确率为0.8408602150537636
# 正类召回率为0.7272727272727273
# 负类召回率为0.8942307692307693
# MCC为0.630288107142
# 94
# SVM的测试集结果：
# 75 183
# 准确率为0.8401075268817204
# 正类召回率为0.7575757575757576
# 负类召回率为0.8798076923076923
# MCC为0.635718535982
# 95
# SVM的测试集结果：
# 74 182
# 准确率为0.8336559139784946
# 正类召回率为0.7474747474747475
# 负类召回率为0.875
# MCC为0.620848776702
# 96
# SVM的测试集结果：
# 73 180
# 准确率为0.8239784946236559
# 正类召回率为0.7373737373737373
# 负类召回率为0.8653846153846154
# MCC为0.599650506788
# 97
# SVM的测试集结果：
# 73 182
# 准确率为0.8305376344086021
# 正类召回率为0.7373737373737373
# 负类召回率为0.875
# MCC为0.612373737374
# 98
# SVM的测试集结果：
# 68 186
# 准确率为0.8276344086021507
# 正类召回率为0.6868686868686869
# 负类召回率为0.8942307692307693
# MCC为0.596689797443
# 99
# SVM的测试集结果：
# 68 185
# 准确率为0.8244086021505377
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 100
# SVM的测试集结果：
# 75 185
# 准确率为0.8466666666666667
# 正类召回率为0.7575757575757576
# 负类召回率为0.8894230769230769
# MCC为0.6487338841
# 101
# SVM的测试集结果：
# 74 183
# 准确率为0.8372043010752689
# 正类召回率为0.7474747474747475
# 负类召回率为0.8798076923076923
# MCC为0.627282439782
# 102
# SVM的测试集结果：
# 66 180
# 准确率为0.8011827956989247
# 正类召回率为0.6666666666666666
# 负类召回率为0.8653846153846154
# MCC为0.539571534759
# 103
# SVM的测试集结果：
# 66 181
# 准确率为0.8047311827956989
# 正类召回率为0.6666666666666666
# 负类召回率为0.8701923076923077
# MCC为0.546086098715
# 104
# SVM的测试集结果：
# 72 182
# 准确率为0.8270967741935484
# 正类召回率为0.7272727272727273
# 负类召回率为0.875
# MCC为0.603887835368
# 105
# SVM的测试集结果：
# 74 179
# 准确率为0.8239784946236559
# 正类召回率为0.7474747474747475
# 负类召回率为0.8605769230769231
# MCC为0.601943951225
# 106
# SVM的测试集结果：
# 72 185
# 准确率为0.8375268817204301
# 正类召回率为0.7272727272727273
# 负类召回率为0.8894230769230769
# MCC为0.623577627463
# 107
# SVM的测试集结果：
# 73 184
# 准确率为0.8369892473118281
# 正类召回率为0.7373737373737373
# 负类召回率为0.8846153846153846
# MCC为0.625369274294
# 108
# SVM的测试集结果：
# 71 181
# 准确率为0.8208602150537635
# 正类召回率为0.7171717171717171
# 负类召回率为0.8701923076923077
# MCC为0.588939152457
# 109
# SVM的测试集结果：
# 69 183
# 准确率为0.8204301075268816
# 正类召回率为0.696969696969697
# 负类召回率为0.8798076923076923
# MCC为0.584929820951
# 110
# SVM的测试集结果：
# 75 183
# 准确率为0.8401075268817205
# 正类召回率为0.7575757575757576
# 负类召回率为0.8798076923076923
# MCC为0.635718535982
# 111
# SVM的测试集结果：
# 71 184
# 准确率为0.8305376344086023
# 正类召回率为0.7171717171717171
# 负类召回率为0.8846153846153846
# MCC为0.608502556069
# 112
# SVM的测试集结果：
# 72 183
# 准确率为0.8308602150537634
# 正类召回率为0.7272727272727273
# 负类召回率为0.8798076923076923
# MCC为0.610379551683
# 113
# SVM的测试集结果：
# 70 180
# 准确率为0.8144086021505377
# 正类召回率为0.7070707070707071
# 负类召回率为0.8653846153846154
# MCC为0.573990469546
# 114
# SVM的测试集结果：
# 73 183
# 准确率为0.8338709677419354
# 正类召回率为0.7373737373737373
# 负类召回率为0.8798076923076923
# MCC为0.618836518278
# 115
# SVM的测试集结果：
# 71 185
# 准确率为0.8338709677419354
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 116
# SVM的测试集结果：
# 69 178
# 准确率为0.8047311827956989
# 正类召回率为0.696969696969697
# 负类召回率为0.8557692307692307
# MCC为0.552738927739
# 117
# SVM的测试集结果：
# 74 187
# 准确率为0.8509677419354841
# 正类召回率为0.7474747474747475
# 负类召回率为0.8990384615384616
# MCC为0.65372777025
# 118
# SVM的测试集结果：
# 71 182
# 准确率为0.8241935483870968
# 正类召回率为0.7171717171717171
# 负类召回率为0.875
# MCC为0.595389829071
# 119
# SVM的测试集结果：
# 67 184
# 准确率为0.8178494623655915
# 正类召回率为0.6767676767676768
# 负类召回率为0.8846153846153846
# MCC为0.574593882062
# 120
# SVM的测试集结果：
# 72 182
# 准确率为0.8279569892473118
# 正类召回率为0.7272727272727273
# 负类召回率为0.875
# MCC为0.603887835368
# 121
# SVM的测试集结果：
# 76 184
# 准确率为0.8472043010752689
# 正类召回率为0.7676767676767676
# 负类召回率为0.8846153846153846
# MCC为0.650588295262
# 122
# SVM的测试集结果：
# 71 183
# 准确率为0.8276344086021507
# 正类召回率为0.7171717171717171
# 负类召回率为0.8798076923076923
# MCC为0.601910296614
# 123
# SVM的测试集结果：
# 71 186
# 准确率为0.8376344086021505
# 正类召回率为0.7171717171717171
# 负类召回率为0.8942307692307693
# MCC为0.621910808035
# 124
# SVM的测试集结果：
# 74 183
# 准确率为0.8374193548387098
# 正类召回率为0.7474747474747475
# 负类召回率为0.8798076923076923
# MCC为0.627282439782
# 125
# SVM的测试集结果：
# 69 184
# 准确率为0.8236559139784946
# 正类召回率为0.696969696969697
# 负类召回率为0.8846153846153846
# MCC为0.591580924307
# 126
# SVM的测试集结果：
# 70 183
# 准确率为0.8236559139784946
# 正类召回率为0.7070707070707071
# 负类召回率为0.8798076923076923
# MCC为0.593427484675
# 127
# SVM的测试集结果：
# 72 179
# 准确率为0.8179569892473119
# 正类召回率为0.7272727272727273
# 负类召回率为0.8605769230769231
# MCC为0.58481867424
# 128
# SVM的测试集结果：
# 73 182
# 准确率为0.8306451612903226
# 正类召回率为0.7373737373737373
# 负类召回率为0.875
# MCC为0.612373737374
# 129
# SVM的测试集结果：
# 74 182
# 准确率为0.8340860215053765
# 正类召回率为0.7474747474747475
# 负类召回率为0.875
# MCC为0.620848776702
# 130
# SVM的测试集结果：
# 72 183
# 准确率为0.8311827956989248
# 正类召回率为0.7272727272727273
# 负类召回率为0.8798076923076923
# MCC为0.610379551683
# 131
# SVM的测试集结果：
# 76 183
# 准确率为0.8427956989247312
# 正类召回率为0.7676767676767676
# 负类召回率为0.8798076923076923
# MCC为0.644146004432
# 132
# SVM的测试集结果：
# 71 181
# 准确率为0.8203225806451613
# 正类召回率为0.7171717171717171
# 负类召回率为0.8701923076923077
# MCC为0.588939152457
# 133
# SVM的测试集结果：
# 72 182
# 准确率为0.8275268817204301
# 正类召回率为0.7272727272727273
# 负类召回率为0.875
# MCC为0.603887835368
# 134
# SVM的测试集结果：
# 71 187
# 准确率为0.8403225806451614
# 正类召回率为0.7171717171717171
# 负类召回率为0.8990384615384616
# MCC为0.628731166364
# 135
# SVM的测试集结果：
# 72 183
# 准确率为0.8301075268817204
# 正类召回率为0.7272727272727273
# 负类召回率为0.8798076923076923
# MCC为0.610379551683
# 136
# SVM的测试集结果：
# 70 184
# 准确率为0.8275268817204301
# 正类召回率为0.7070707070707071
# 负类召回率为0.8846153846153846
# MCC为0.600049249681
# 137
# SVM的测试集结果：
# 71 183
# 准确率为0.8269892473118279
# 正类召回率为0.7171717171717171
# 负类召回率为0.8798076923076923
# MCC为0.601910296614
# 138
# SVM的测试集结果：
# 74 183
# 准确率为0.8379569892473118
# 正类召回率为0.7474747474747475
# 负类召回率为0.8798076923076923
# MCC为0.627282439782
# 139
# SVM的测试集结果：
# 67 184
# 准确率为0.8178494623655913
# 正类召回率为0.6767676767676768
# 负类召回率为0.8846153846153846
# MCC为0.574593882062
# 140
# SVM的测试集结果：
# 74 182
# 准确率为0.8339784946236559
# 正类召回率为0.7474747474747475
# 负类召回率为0.875
# MCC为0.620848776702
# 141
# SVM的测试集结果：
# 71 183
# 准确率为0.8273118279569893
# 正类召回率为0.7171717171717171
# 负类召回率为0.8798076923076923
# MCC为0.601910296614
# 142
# SVM的测试集结果：
# 74 182
# 准确率为0.8336559139784947
# 正类召回率为0.7474747474747475
# 负类召回率为0.875
# MCC为0.620848776702
# 143
# SVM的测试集结果：
# 78 180
# 准确率为0.8406451612903225
# 正类召回率为0.7878787878787878
# 负类召回率为0.8653846153846154
# MCC为0.642224149861
# 144
# SVM的测试集结果：
# 72 185
# 准确率为0.8373118279569892
# 正类召回率为0.7272727272727273
# 负类召回率为0.8894230769230769
# MCC为0.623577627463
# 145
# SVM的测试集结果：
# 73 181
# 准确率为0.8275268817204301
# 正类召回率为0.7373737373737373
# 负类召回率为0.8701923076923077
# MCC为0.605979017423
# 146
# SVM的测试集结果：
# 67 184
# 准确率为0.817741935483871
# 正类召回率为0.6767676767676768
# 负类召回率为0.8846153846153846
# MCC为0.574593882062
# 147
# SVM的测试集结果：
# 76 184
# 准确率为0.8466666666666667
# 正类召回率为0.7676767676767676
# 负类召回率为0.8846153846153846
# MCC为0.650588295262
# 148
# SVM的测试集结果：
# 74 183
# 准确率为0.8373118279569894
# 正类召回率为0.7474747474747475
# 负类召回率为0.8798076923076923
# MCC为0.627282439782
# 149
# SVM的测试集结果：
# 68 187
# 准确率为0.830967741935484
# 正类召回率为0.6868686868686869
# 负类召回率为0.8990384615384616
# MCC为0.603607755688
# 150
# SVM的测试集结果：
# 76 181
# 准确率为0.8366666666666667
# 正类召回率为0.7676767676767676
# 负类召回率为0.8701923076923077
# MCC为0.631461848042
# 151
# SVM的测试集结果：
# 72 183
# 准确率为0.8308602150537634
# 正类召回率为0.7272727272727273
# 负类召回率为0.8798076923076923
# MCC为0.610379551683
# 152
# SVM的测试集结果：
# 67 185
# 准确率为0.8208602150537635
# 正类召回率为0.6767676767676768
# 负类召回率为0.8894230769230769
# MCC为0.58138110884
# 153
# SVM的测试集结果：
# 71 184
# 准确率为0.8311827956989248
# 正类召回率为0.7171717171717171
# 负类召回率为0.8846153846153846
# MCC为0.608502556069
# 154
# SVM的测试集结果：
# 76 186
# 准确率为0.8531182795698925
# 正类召回率为0.7676767676767676
# 负类召回率为0.8942307692307693
# MCC为0.66368256701
# 155
# SVM的测试集结果：
# 68 186
# 准确率为0.827204301075269
# 正类召回率为0.6868686868686869
# 负类召回率为0.8942307692307693
# MCC为0.596689797443
# 156
# SVM的测试集结果：
# 73 184
# 准确率为0.8372043010752688
# 正类召回率为0.7373737373737373
# 负类召回率为0.8846153846153846
# MCC为0.625369274294
# 157
# SVM的测试集结果：
# 73 184
# 准确率为0.8365591397849462
# 正类召回率为0.7373737373737373
# 负类召回率为0.8846153846153846
# MCC为0.625369274294
# 158
# SVM的测试集结果：
# 69 184
# 准确率为0.8237634408602151
# 正类召回率为0.696969696969697
# 负类召回率为0.8846153846153846
# MCC为0.591580924307
# 159
# SVM的测试集结果：
# 76 186
# 准确率为0.8536559139784947
# 正类召回率为0.7676767676767676
# 负类召回率为0.8942307692307693
# MCC为0.66368256701
# 160
# SVM的测试集结果：
# 76 185
# 准确率为0.8500000000000002
# 正类召回率为0.7676767676767676
# 负类召回率为0.8894230769230769
# MCC为0.6570998446
# 161
# SVM的测试集结果：
# 75 187
# 准确率为0.8537634408602152
# 正类召回率为0.7575757575757576
# 负类召回率为0.8990384615384616
# MCC为0.662037673515
# 162
# SVM的测试集结果：
# 74 185
# 准确率为0.8432258064516128
# 正类召回率为0.7474747474747475
# 负类召回率为0.8894230769230769
# MCC为0.640358996906
# 163
# SVM的测试集结果：
# 71 183
# 准确率为0.8273118279569893
# 正类召回率为0.7171717171717171
# 负类召回率为0.8798076923076923
# MCC为0.601910296614
# 164
# SVM的测试集结果：
# 71 185
# 准确率为0.8339784946236559
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 165
# SVM的测试集结果：
# 72 181
# 准确率为0.8237634408602151
# 正类召回率为0.7272727272727273
# 负类召回率为0.8701923076923077
# MCC为0.597465034965
# 166
# SVM的测试集结果：
# 71 185
# 准确率为0.8340860215053765
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 167
# SVM的测试集结果：
# 75 183
# 准确率为0.8400000000000001
# 正类召回率为0.7575757575757576
# 负类召回率为0.8798076923076923
# MCC为0.635718535982
# 168
# SVM的测试集结果：
# 73 185
# 准确率为0.8401075268817204
# 正类召回率为0.7373737373737373
# 负类召回率为0.8894230769230769
# MCC为0.631973985065
# 169
# SVM的测试集结果：
# 72 185
# 准确率为0.8365591397849462
# 正类召回率为0.7272727272727273
# 负类召回率为0.8894230769230769
# MCC为0.623577627463
# 170
# SVM的测试集结果：
# 73 183
# 准确率为0.833763440860215
# 正类召回率为0.7373737373737373
# 负类召回率为0.8798076923076923
# MCC为0.618836518278
# 171
# SVM的测试集结果：
# 69 184
# 准确率为0.8237634408602151
# 正类召回率为0.696969696969697
# 负类召回率为0.8846153846153846
# MCC为0.591580924307
# 172
# SVM的测试集结果：
# 70 184
# 准确率为0.8272043010752688
# 正类召回率为0.7070707070707071
# 负类召回率为0.8846153846153846
# MCC为0.600049249681
# 173
# SVM的测试集结果：
# 74 184
# 准确率为0.8403225806451614
# 正类召回率为0.7474747474747475
# 负类召回率为0.8846153846153846
# MCC为0.633785201189
# 174
# SVM的测试集结果：
# 72 185
# 准确率为0.8369892473118279
# 正类召回率为0.7272727272727273
# 负类召回率为0.8894230769230769
# MCC为0.623577627463
# 175
# SVM的测试集结果：
# 74 185
# 准确率为0.843978494623656
# 正类召回率为0.7474747474747475
# 负类召回率为0.8894230769230769
# MCC为0.640358996906
# 176
# SVM的测试集结果：
# 69 185
# 准确率为0.8274193548387098
# 正类召回率为0.696969696969697
# 负类召回率为0.8894230769230769
# MCC为0.59830789139
# 177
# SVM的测试集结果：
# 76 182
# 准确率为0.8404301075268817
# 正类召回率为0.7676767676767676
# 负类召回率为0.875
# MCC为0.637771119698
# 178
# SVM的测试集结果：
# 71 186
# 准确率为0.8374193548387098
# 正类召回率为0.7171717171717171
# 负类召回率为0.8942307692307693
# MCC为0.621910808035
# 179
# SVM的测试集结果：
# 75 180
# 准确率为0.8308602150537634
# 正类召回率为0.7575757575757576
# 负类召回率为0.8653846153846154
# MCC为0.616702899633
# 180
# SVM的测试集结果：
# 72 185
# 准确率为0.8377419354838709
# 正类召回率为0.7272727272727273
# 负类召回率为0.8894230769230769
# MCC为0.623577627463
# 181
# SVM的测试集结果：
# 79 182
# 准确率为0.8501075268817205
# 正类召回率为0.797979797979798
# 负类召回率为0.875
# MCC为0.663102946887
# 182
# SVM的测试集结果：
# 69 183
# 准确率为0.8207526881720432
# 正类召回率为0.696969696969697
# 负类召回率为0.8798076923076923
# MCC为0.584929820951
# 183
# SVM的测试集结果：
# 75 179
# 准确率为0.8274193548387097
# 正类召回率为0.7575757575757576
# 负类召回率为0.8605769230769231
# MCC为0.610492500232
# 184
# SVM的测试集结果：
# 75 181
# 准确率为0.8340860215053765
# 正类召回率为0.7575757575757576
# 负类召回率为0.8701923076923077
# MCC为0.622976217647
# 185
# SVM的测试集结果：
# 72 182
# 准确率为0.8276344086021507
# 正类召回率为0.7272727272727273
# 负类召回率为0.875
# MCC为0.603887835368
# 186
# SVM的测试集结果：
# 74 181
# 准确率为0.8305376344086021
# 正类召回率为0.7474747474747475
# 负类召回率为0.8701923076923077
# MCC为0.614482339336
# 187
# SVM的测试集结果：
# 75 181
# 准确率为0.8343010752688172
# 正类召回率为0.7575757575757576
# 负类召回率为0.8701923076923077
# MCC为0.622976217647
# 188
# SVM的测试集结果：
# 78 183
# 准确率为0.85
# 正类召回率为0.7878787878787878
# 负类召回率为0.8798076923076923
# MCC为0.66097974486
# 189
# SVM的测试集结果：
# 72 183
# 准确率为0.8301075268817204
# 正类召回率为0.7272727272727273
# 负类召回率为0.8798076923076923
# MCC为0.610379551683
# 190
# SVM的测试集结果：
# 77 180
# 准确率为0.8373118279569892
# 正类召回率为0.7777777777777778
# 负类召回率为0.8653846153846154
# MCC为0.633723151146
# 191
# SVM的测试集结果：
# 75 183
# 准确率为0.8403225806451614
# 正类召回率为0.7575757575757576
# 负类召回率为0.8798076923076923
# MCC为0.635718535982
# 192
# SVM的测试集结果：
# 68 185
# 准确率为0.8245161290322581
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 193
# SVM的测试集结果：
# 74 186
# 准确率为0.8463440860215053
# 正类召回率为0.7474747474747475
# 负类召回率为0.8942307692307693
# MCC为0.64700582929
# 194
# SVM的测试集结果：
# 72 183
# 准确率为0.8311827956989248
# 正类召回率为0.7272727272727273
# 负类召回率为0.8798076923076923
# MCC为0.610379551683
# 195
# SVM的测试集结果：
# 67 185
# 准确率为0.8211827956989248
# 正类召回率为0.6767676767676768
# 负类召回率为0.8894230769230769
# MCC为0.58138110884
# 196
# SVM的测试集结果：
# 69 186
# 准确率为0.8305376344086023
# 正类召回率为0.696969696969697
# 负类召回率为0.8942307692307693
# MCC为0.605112968878
# 197
# SVM的测试集结果：
# 74 183
# 准确率为0.8369892473118279
# 正类召回率为0.7474747474747475
# 负类召回率为0.8798076923076923
# MCC为0.627282439782
# 198
# SVM的测试集结果：
# 77 183
# 准确率为0.8472043010752689
# 正类召回率为0.7777777777777778
# 负类召回率为0.8798076923076923
# MCC为0.652566021749
# 199

# %%
a = np.array(MCC)

np.savetxt('./2anova/MCC.csv',a, delimiter = ',')

# %%
#-*-coding:utf-8-*-
import itertools as iters
from time import time
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.cross_validation import KFold
from sklearn.feature_selection import f_classif
from sklearn.grid_search import GridSearchCV
from sklearn.svm import SVC
import matplotlib.pylab as plt
from math import log2 
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import accuracy_score
from sklearn import metrics

def entropy(data):
    length,dataDict=len(data),{} 
    for b in data:  
        try:dataDict[b]+=1  
        except:dataDict[b]=1  
    entropy=sum([-d/length*log2(d/length) for d in list(dataDict.values())])
    return entropy

def informationgain(data,label):
    informationgain = []
    la = entropy(label)
    print(la)
    for j in range(data.shape[1] ):
        feature = data[:,j]
        for a in set(feature):
            ent = []
            op = []
            ne = []
            for k in range(len(feature)):
                if feature[k] >= a:
                    op.append(label[k])
                else:
                    ne.append(label[k])
            if len(op) == 0 or len(ne) == 0:
                ent.append(la)
            else:
                ent.append(len(op)*entropy(op)/len(label) + len(ne)*entropy(ne)/len(label))
        informationgain.append(la-min(ent))
    return informationgain

##计算二肽特征
def statisPsi(seqs, protein, gap):
    psi = np.zeros(len(seqs))
    loops = len(protein) - gap - 1
    for start in range(loops):
        dipeptide = protein[start] + protein[start + gap + 1]
        index = seqs.index(dipeptide)
        psi[index] += 1
    psi = np.array(psi)
    psi = psi / sum(psi)
    return psi


# get gap dipeptide features psi matrix",
def all_psi(dataset,gap):
    gap_psi = np.zeros((len(dataset), len(DIPEPTIDE)))
    for idx in range(len(dataset)):
        gap_psi[idx] = statisPsi(DIPEPTIDE, dataset[idx], gap)
    return gap_psi

#输入核函数名称和参数gamma值，返回SVM训练十折交叉验证的准确率
def SVM_10fold(data,label):
    ##数据归一化（按列处理，必须做）
    scaler = preprocessing.StandardScaler().fit(data)
    data = scaler.transform(data)
    kf = KFold(data.shape[0],n_folds=10,shuffle = True)  #固定随机数可固定分组
    precision_average = 0.0
    TPCount = 0
    TNCount = 0
    train = []
    test = []
    test_true = []

    C_range = np.logspace(15, 5, 11, base=2)
    gamma_range = np.logspace(-15, -25, 11, base=2)
    param_grid = dict(gamma=gamma_range, C=C_range)
    grid = GridSearchCV(SVC(kernel='rbf'), param_grid=param_grid, cv=5)  # 基于交叉验证的网格搜索

    for train_index, test_index in kf:
        grid = grid.fit(data[train_index],label[train_index])
        clf = SVC(C = grid.best_params_['C'],gamma=grid.best_params_['gamma'])
        clf.fit(data[train_index],label[train_index])
        pred_train = clf.predict(data[train_index]).tolist()
        pred_test = clf.predict(data[test_index]).tolist()

        train.append(pred_train)

        test = test + pred_test
        test_true = test_true + label[test_index].tolist()

        testLabel = label[test_index]

        # print(metrics.confusion_matrix(pred_train,trainLabel))
        TP = 0
        TN = 0
        #同时输出svm的结果
        #查看测试集的结果
        for i in range(len(pred_test)):
            if pred_test[i] == 1 and (testLabel[i] == 1):
                TP = TP + 1
            elif pred_test[i] == 0 and (testLabel[i] == 0):
                TN = TN + 1
        TPCount = TPCount + TP
        TNCount = TNCount + TN

        precision = (TP + TN) * 1.0 / len(testLabel)
        precision_average = precision_average + precision


    precision_average = precision_average / 10
    positiveReca1 = TPCount * 1.0 / 99
    negtiveReca1 = TNCount * 1.0 / 208
    MCC = matthews_corrcoef(test_true,test)


    print (u'SVM的测试集结果：')
    print (TPCount,TNCount)
    print (u'准确率为' + str(precision_average))
    print (u'正类召回率为' + str(positiveReca1))
    print (u'负类召回率为' + str(negtiveReca1))
    print(u'MCC为' + str(matthews_corrcoef(test_true,test)))
    print(accuracy_score(test_true,test))


    # ##保存最优模型的训练、测试集结果
    # with open('C:\\Users\Administrator\Desktop\data\\result\\result_4gapTC_svm_train.txt','w') as file:
    #     for i in train:
    #         file.write(str(i) + '\n')
    # with open('C:\\Users\Administrator\Desktop\data\\result\\result_4gapTC_svm_test.txt','w') as file:
    #     for i in test:
    #         file.write(str(i) + '\n')


    return precision_average,positiveReca1,negtiveReca1,MCC

if(__name__=='__main__'):
    # t0 = time()
    path = r''
    with open('virion.txt', "r") as file:
        train_tdata = [line.strip() for line in file if '>' != line[0]]
    with open( 'non-virion.txt', "r") as file:
        train_fdata = [line.strip() for line in file if '>' != line[0]]

    SAA = ('ACDEFGHIKLMNPQRSTVWY')
    DIPEPTIDE = []
    print('1')
    for dipeptide in iters.product(SAA, repeat=2):
        DIPEPTIDE.append(''.join(dipeptide))

    label = pd.Series([1 for i in range(len(train_tdata))]+ [0 for i in range(len(train_fdata))])
    label = label.as_matrix()

    ##将序列处理为特征向量
    gap = 1

    gap_T = all_psi(train_tdata,gap)
    gap_F = all_psi(train_fdata,gap)

    dataAll = np.row_stack((gap_T, gap_F))  # 矩阵按行合并
    # print(data.shape)
    ##将特征结果保存，方便下次直接读取
    # np.savetxt('E:\Python Program\Protein\data\gapAll\\virion_gap0_dipe2.csv', data, delimiter=',')
    ##直接读入特征数据
    # dataAll = pd.read_csv(path = '\\virion_gap0_dipe2.csv',header=None).as_matrix()


    print(dataAll.shape)
    ##计算F值（informationgain）
    f = informationgain(dataAll, label)

    #因为三肽特征较为稀疏，会有一些全为nan的列，要对这些列进行处理
    a = np.array(f)
    nan_count = np.sum(a != a)
    print(nan_count)
    ##将nan替换为0
    f1 = np.nan_to_num(a)
    #将F值从大到小排序，获得相应的位置序号
    f_order = np.argsort(f).tolist()[::-1]

    #选取所需的特征维度，构造模型
    data = dataAll[:,f_order[0:189]]
    acc = []
    pr = []
    nr = []
    MCC = []
    for cishu in range(200):
        presion,positiveRecall,negtiveRecall,matthews = SVM_10fold(data,label)
        acc.append(presion)
        pr.append(positiveRecall)
        nr.append(negtiveRecall)
        MCC.append(matthews)
    


    ###为了选取最优特征子集，一般需要遍历，结果运行、保存、展示如下
#     p = []
#     for i in range(1,dataAll.shape[1]+1):
#         data = dataAll[:,f_order[0:i]]
#         print(data.shape)
#         presion, positiveRecall, negtiveRecall = SVM_10fold(data, label)
#         p.append(presion)
#     # print(SVM_10fold(data,label))
#     np.savetxt(str(gap)+'informationgainstatisPsi.csv',p,delimiter=',')
#     plt.plot(range(len(p)),p)
#     plt.savefig(str(gap)+'informationgainstatisPsi.pdf')
#     plt.close()
# Out:
# D:\softwares\Anaconda\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# D:\softwares\Anaconda\lib\site-packages\sklearn\grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# 1
# (307, 400)
# 0.9070532598287184
# 0
# SVM的测试集结果：
# 70 186
# 准确率为0.8341935483870969
# 正类召回率为0.7070707070707071
# 负类召回率为0.8942307692307693
# MCC为0.613519528877
# 0.833876221498
# SVM的测试集结果：
# 69 187
# 准确率为0.8336559139784946
# 正类召回率为0.696969696969697
# 负类召回率为0.8990384615384616
# MCC为0.611998486045
# 0.833876221498
# SVM的测试集结果：
# 68 187
# 准确率为0.8305376344086021
# 正类召回率为0.6868686868686869
# 负类召回率为0.8990384615384616
# MCC为0.603607755688
# 0.830618892508
# SVM的测试集结果：
# 70 188
# 准确率为0.8404301075268817
# 正类召回率为0.7070707070707071
# 负类召回率为0.9038461538461539
# MCC为0.627307174647
# 0.840390879479
# SVM的测试集结果：
# 63 185
# 准确率为0.8082795698924732
# 正类召回率为0.6363636363636364
# 负类召回率为0.8894230769230769
# MCC为0.547284955116
# 0.807817589577
# SVM的测试集结果：
# 68 185
# 准确率为0.8239784946236559
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 0.824104234528
# SVM的测试集结果：
# 73 183
# 准确率为0.833763440860215
# 正类召回率为0.7373737373737373
# 负类召回率为0.8798076923076923
# MCC为0.618836518278
# 0.833876221498
# SVM的测试集结果：
# 68 185
# 准确率为0.8243010752688174
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 0.824104234528
# SVM的测试集结果：
# 71 185
# 准确率为0.8344086021505376
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 0.833876221498
# SVM的测试集结果：
# 68 186
# 准确率为0.8275268817204303
# 正类召回率为0.6868686868686869
# 负类召回率为0.8942307692307693
# MCC为0.596689797443
# 0.827361563518
# SVM的测试集结果：
# 69 183
# 准确率为0.8206451612903226
# 正类召回率为0.696969696969697
# 负类召回率为0.8798076923076923
# MCC为0.584929820951
# 0.820846905537
# SVM的测试集结果：
# 71 186
# 准确率为0.8369892473118279
# 正类召回率为0.7171717171717171
# 负类召回率为0.8942307692307693
# MCC为0.621910808035
# 0.837133550489
# SVM的测试集结果：
# 66 187
# 准确率为0.8238709677419356
# 正类召回率为0.6666666666666666
# 负类召回率为0.8990384615384616
# MCC为0.586770692238
# 0.824104234528
# SVM的测试集结果：
# 74 184
# 准确率为0.8393548387096775
# 正类召回率为0.7474747474747475
# 负类召回率为0.8846153846153846
# MCC为0.633785201189
# 0.840390879479
# SVM的测试集结果：
# 65 184
# 准确率为0.8108602150537635
# 正类召回率为0.6565656565656566
# 负类召回率为0.8846153846153846
# MCC为0.557530445867
# 0.811074918567
# SVM的测试集结果：
# 70 187
# 准确率为0.8373118279569892
# 正类召回率为0.7070707070707071
# 负类召回率为0.8990384615384616
# MCC为0.620372512285
# 0.837133550489
# SVM的测试集结果：
# 62 183
# 准确率为0.797741935483871
# 正类召回率为0.6262626262626263
# 负类召回率为0.8798076923076923
# MCC为0.524915218801
# 0.798045602606
# SVM的测试集结果：
# 66 186
# 准确率为0.8206451612903226
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 0.820846905537
# SVM的测试集结果：
# 70 187
# 准确率为0.8367741935483872
# 正类召回率为0.7070707070707071
# 负类召回率为0.8990384615384616
# MCC为0.620372512285
# 0.837133550489
# SVM的测试集结果：
# 68 184
# 准确率为0.8208602150537635
# 正类召回率为0.6868686868686869
# 负类召回率为0.8846153846153846
# MCC为0.583096253903
# 0.820846905537
# SVM的测试集结果：
# 70 185
# 准确率为0.8300000000000001
# 正类召回率为0.7070707070707071
# 负类召回率为0.8894230769230769
# MCC为0.606745866171
# 0.830618892508
# SVM的测试集结果：
# 69 185
# 准确率为0.8275268817204301
# 正类召回率为0.696969696969697
# 负类召回率为0.8894230769230769
# MCC为0.59830789139
# 0.827361563518
# SVM的测试集结果：
# 68 185
# 准确率为0.8241935483870968
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 0.824104234528
# SVM的测试集结果：
# 70 185
# 准确率为0.8304301075268817
# 正类召回率为0.7070707070707071
# 负类召回率为0.8894230769230769
# MCC为0.606745866171
# 0.830618892508
# SVM的测试集结果：
# 68 186
# 准确率为0.8274193548387098
# 正类召回率为0.6868686868686869
# 负类召回率为0.8942307692307693
# MCC为0.596689797443
# 0.827361563518
# SVM的测试集结果：
# 66 185
# 准确率为0.8170967741935484
# 正类召回率为0.6666666666666666
# 负类召回率为0.8894230769230769
# MCC为0.57288954914
# 0.817589576547
# SVM的测试集结果：
# 68 187
# 准确率为0.8306451612903226
# 正类召回率为0.6868686868686869
# 负类召回率为0.8990384615384616
# MCC为0.603607755688
# 0.830618892508
# SVM的测试集结果：
# 68 185
# 准确率为0.8241935483870968
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 0.824104234528
# SVM的测试集结果：
# 65 187
# 准确率为0.8208602150537635
# 正类召回率为0.6565656565656566
# 负类召回率为0.8990384615384616
# MCC为0.578321526875
# 0.820846905537
# SVM的测试集结果：
# 69 182
# 准确率为0.8178494623655913
# 正类召回率为0.696969696969697
# 负类召回率为0.875
# MCC为0.578352413281
# 0.817589576547
# SVM的测试集结果：
# 69 186
# 准确率为0.8311827956989248
# 正类召回率为0.696969696969697
# 负类召回率为0.8942307692307693
# MCC为0.605112968878
# 0.830618892508
# SVM的测试集结果：
# 68 183
# 准确率为0.8178494623655915
# 正类召回率为0.6868686868686869
# 负类召回率为0.8798076923076923
# MCC为0.576415982443
# 0.817589576547
# SVM的测试集结果：
# 67 187
# 准确率为0.8275268817204301
# 正类召回率为0.6767676767676768
# 负类召回率为0.8990384615384616
# MCC为0.595198957125
# 0.827361563518
# SVM的测试集结果：
# 69 180
# 准确率为0.8110752688172044
# 正类召回率为0.696969696969697
# 负类召回率为0.8653846153846154
# MCC为0.565410383848
# 0.811074918567
# SVM的测试集结果：
# 65 187
# 准确率为0.8208602150537635
# 正类召回率为0.6565656565656566
# 负类召回率为0.8990384615384616
# MCC为0.578321526875
# 0.820846905537
# SVM的测试集结果：
# 64 180
# 准确率为0.7945161290322581
# 正类召回率为0.6464646464646465
# 负类召回率为0.8653846153846154
# MCC为0.522249703955
# 0.794788273616
# SVM的测试集结果：
# 75 184
# 准确率为0.8434408602150537
# 正类召回率为0.7575757575757576
# 负类召回率为0.8846153846153846
# MCC为0.642191142191
# 0.843648208469
# SVM的测试集结果：
# 68 186
# 准确率为0.8281720430107526
# 正类召回率为0.6868686868686869
# 负类召回率为0.8942307692307693
# MCC为0.596689797443
# 0.827361563518
# SVM的测试集结果：
# 64 187
# 准确率为0.8181720430107526
# 正类召回率为0.6464646464646465
# 负类召回率为0.8990384615384616
# MCC为0.56984998873
# 0.817589576547
# SVM的测试集结果：
# 67 185
# 准确率为0.8206451612903226
# 正类召回率为0.6767676767676768
# 负类召回率为0.8894230769230769
# MCC为0.58138110884
# 0.820846905537
# SVM的测试集结果：
# 67 186
# 准确率为0.8244086021505377
# 正类召回率为0.6767676767676768
# 负类召回率为0.8942307692307693
# MCC为0.588248652414
# 0.824104234528
# SVM的测试集结果：
# 64 185
# 准确率为0.8112903225806452
# 正类召回率为0.6464646464646465
# 负类召回率为0.8894230769230769
# MCC为0.55584295552
# 0.811074918567
# SVM的测试集结果：
# 67 186
# 准确率为0.8241935483870968
# 正类召回率为0.6767676767676768
# 负类召回率为0.8942307692307693
# MCC为0.588248652414
# 0.824104234528
# SVM的测试集结果：
# 67 188
# 准确率为0.8308602150537636
# 正类召回率为0.6767676767676768
# 负类召回率为0.9038461538461539
# MCC为0.602234560597
# 0.830618892508
# SVM的测试集结果：
# 67 185
# 准确率为0.8213978494623657
# 正类召回率为0.6767676767676768
# 负类召回率为0.8894230769230769
# MCC为0.58138110884
# 0.820846905537
# SVM的测试集结果：
# 67 187
# 准确率为0.8274193548387098
# 正类召回率为0.6767676767676768
# 负类召回率为0.8990384615384616
# MCC为0.595198957125
# 0.827361563518
# SVM的测试集结果：
# 67 185
# 准确率为0.8207526881720429
# 正类召回率为0.6767676767676768
# 负类召回率为0.8894230769230769
# MCC为0.58138110884
# 0.820846905537
# SVM的测试集结果：
# 66 186
# 准确率为0.8208602150537635
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 0.820846905537
# SVM的测试集结果：
# 67 184
# 准确率为0.8178494623655913
# 正类召回率为0.6767676767676768
# 负类召回率为0.8846153846153846
# MCC为0.574593882062
# 0.817589576547
# SVM的测试集结果：
# 71 181
# 准确率为0.8208602150537635
# 正类召回率为0.7171717171717171
# 负类召回率为0.8701923076923077
# MCC为0.588939152457
# 0.820846905537
# SVM的测试集结果：
# 66 186
# 准确率为0.8203225806451613
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 0.820846905537
# SVM的测试集结果：
# 70 185
# 准确率为0.8306451612903226
# 正类召回率为0.7070707070707071
# 负类召回率为0.8894230769230769
# MCC为0.606745866171
# 0.830618892508
# SVM的测试集结果：
# 67 184
# 准确率为0.8172043010752688
# 正类召回率为0.6767676767676768
# 负类召回率为0.8846153846153846
# MCC为0.574593882062
# 0.817589576547
# SVM的测试集结果：
# 70 185
# 准确率为0.830752688172043
# 正类召回率为0.7070707070707071
# 负类召回率为0.8894230769230769
# MCC为0.606745866171
# 0.830618892508
# SVM的测试集结果：
# 66 186
# 准确率为0.8210752688172043
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 0.820846905537
# SVM的测试集结果：
# 65 184
# 准确率为0.8110752688172044
# 正类召回率为0.6565656565656566
# 负类召回率为0.8846153846153846
# MCC为0.557530445867
# 0.811074918567
# SVM的测试集结果：
# 67 185
# 准确率为0.8209677419354838
# 正类召回率为0.6767676767676768
# 负类召回率为0.8894230769230769
# MCC为0.58138110884
# 0.820846905537
# SVM的测试集结果：
# 64 188
# 准确率为0.8212903225806452
# 正类召回率为0.6464646464646465
# 负类召回率为0.9038461538461539
# MCC为0.576985934847
# 0.820846905537
# SVM的测试集结果：
# 66 187
# 准确率为0.8241935483870968
# 正类召回率为0.6666666666666666
# 负类召回率为0.8990384615384616
# MCC为0.586770692238
# 0.824104234528
# SVM的测试集结果：
# 66 185
# 准确率为0.8175268817204302
# 正类召回率为0.6666666666666666
# 负类召回率为0.8894230769230769
# MCC为0.57288954914
# 0.817589576547
# SVM的测试集结果：
# 66 186
# 准确率为0.8208602150537635
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 0.820846905537
# SVM的测试集结果：
# 69 185
# 准确率为0.8276344086021507
# 正类召回率为0.696969696969697
# 负类召回率为0.8894230769230769
# MCC为0.59830789139
# 0.827361563518
# SVM的测试集结果：
# 68 183
# 准确率为0.8176344086021505
# 正类召回率为0.6868686868686869
# 负类召回率为0.8798076923076923
# MCC为0.576415982443
# 0.817589576547
# SVM的测试集结果：
# 66 187
# 准确率为0.8238709677419355
# 正类召回率为0.6666666666666666
# 负类召回率为0.8990384615384616
# MCC为0.586770692238
# 0.824104234528
# SVM的测试集结果：
# 72 184
# 准确率为0.833763440860215
# 正类召回率为0.7272727272727273
# 负类召回率为0.8846153846153846
# MCC为0.61694214084
# 0.833876221498
# SVM的测试集结果：
# 72 184
# 准确率为0.8341935483870968
# 正类召回率为0.7272727272727273
# 负类召回率为0.8846153846153846
# MCC为0.61694214084
# 0.833876221498
# SVM的测试集结果：
# 63 184
# 准确率为0.8046236559139786
# 正类召回率为0.6363636363636364
# 负类召回率为0.8846153846153846
# MCC为0.54037908716
# 0.804560260586
# SVM的测试集结果：
# 68 188
# 准确率为0.8336559139784946
# 正类召回率为0.6868686868686869
# 负类召回率为0.9038461538461539
# MCC为0.610609776037
# 0.833876221498
# SVM的测试集结果：
# 65 187
# 准确率为0.8208602150537635
# 正类召回率为0.6565656565656566
# 负类召回率为0.8990384615384616
# MCC为0.578321526875
# 0.820846905537
# SVM的测试集结果：
# 66 185
# 准确率为0.817741935483871
# 正类召回率为0.6666666666666666
# 负类召回率为0.8894230769230769
# MCC为0.57288954914
# 0.817589576547
# SVM的测试集结果：
# 71 186
# 准确率为0.8370967741935484
# 正类召回率为0.7171717171717171
# 负类召回率为0.8942307692307693
# MCC为0.621910808035
# 0.837133550489
# SVM的测试集结果：
# 65 185
# 准确率为0.8147311827956989
# 正类召回率为0.6565656565656566
# 负类召回率为0.8894230769230769
# MCC为0.564377319301
# 0.814332247557
# SVM的测试集结果：
# 72 187
# 准确率为0.8435483870967742
# 正类召回率为0.7272727272727273
# 负类召回率为0.8990384615384616
# MCC为0.637075749899
# 0.843648208469
# SVM的测试集结果：
# 68 183
# 准确率为0.8178494623655913
# 正类召回率为0.6868686868686869
# 负类召回率为0.8798076923076923
# MCC为0.576415982443
# 0.817589576547
# SVM的测试集结果：
# 69 185
# 准确率为0.8278494623655914
# 正类召回率为0.696969696969697
# 负类召回率为0.8894230769230769
# MCC为0.59830789139
# 0.827361563518
# SVM的测试集结果：
# 72 185
# 准确率为0.8372043010752688
# 正类召回率为0.7272727272727273
# 负类召回率为0.8894230769230769
# MCC为0.623577627463
# 0.837133550489
# SVM的测试集结果：
# 65 185
# 准确率为0.8140860215053763
# 正类召回率为0.6565656565656566
# 负类召回率为0.8894230769230769
# MCC为0.564377319301
# 0.814332247557
# SVM的测试集结果：
# 70 186
# 准确率为0.8343010752688172
# 正类召回率为0.7070707070707071
# 负类召回率为0.8942307692307693
# MCC为0.613519528877
# 0.833876221498
# SVM的测试集结果：
# 68 185
# 准确率为0.8239784946236559
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 0.824104234528
# SVM的测试集结果：
# 66 186
# 准确率为0.8208602150537635
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 0.820846905537
# SVM的测试集结果：
# 66 186
# 准确率为0.8204301075268818
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 0.820846905537
# SVM的测试集结果：
# 67 183
# 准确率为0.8140860215053763
# 正类召回率为0.6767676767676768
# 负类召回率为0.8798076923076923
# MCC为0.567884616416
# 0.814332247557
# SVM的测试集结果：
# 66 182
# 准确率为0.8075268817204302
# 正类召回率为0.6666666666666666
# 负类召回率为0.875
# MCC为0.552672978929
# 0.807817589577
# SVM的测试集结果：
# 66 185
# 准确率为0.8172043010752688
# 正类召回率为0.6666666666666666
# 负类召回率为0.8894230769230769
# MCC为0.57288954914
# 0.817589576547
# SVM的测试集结果：
# 69 183
# 准确率为0.8204301075268818
# 正类召回率为0.696969696969697
# 负类召回率为0.8798076923076923
# MCC为0.584929820951
# 0.820846905537
# SVM的测试集结果：
# 68 187
# 准确率为0.8305376344086023
# 正类召回率为0.6868686868686869
# 负类召回率为0.8990384615384616
# MCC为0.603607755688
# 0.830618892508
# SVM的测试集结果：
# 66 182
# 准确率为0.8078494623655914
# 正类召回率为0.6666666666666666
# 负类召回率为0.875
# MCC为0.552672978929
# 0.807817589577
# SVM的测试集结果：
# 67 186
# 准确率为0.8244086021505377
# 正类召回率为0.6767676767676768
# 负类召回率为0.8942307692307693
# MCC为0.588248652414
# 0.824104234528
# SVM的测试集结果：
# 66 186
# 准确率为0.8211827956989248
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 0.820846905537
# SVM的测试集结果：
# 74 184
# 准确率为0.8404301075268817
# 正类召回率为0.7474747474747475
# 负类召回率为0.8846153846153846
# MCC为0.633785201189
# 0.840390879479
# SVM的测试集结果：
# 66 186
# 准确率为0.8205376344086023
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 0.820846905537
# SVM的测试集结果：
# 70 184
# 准确率为0.8273118279569893
# 正类召回率为0.7070707070707071
# 负类召回率为0.8846153846153846
# MCC为0.600049249681
# 0.827361563518
# SVM的测试集结果：
# 71 184
# 准确率为0.830215053763441
# 正类召回率为0.7171717171717171
# 负类召回率为0.8846153846153846
# MCC为0.608502556069
# 0.830618892508
# SVM的测试集结果：
# 70 184
# 准确率为0.8270967741935484
# 正类召回率为0.7070707070707071
# 负类召回率为0.8846153846153846
# MCC为0.600049249681
# 0.827361563518
# SVM的测试集结果：
# 66 184
# 准确率为0.8141935483870968
# 正类召回率为0.6666666666666666
# 负类召回率为0.8846153846153846
# MCC为0.566072420238
# 0.814332247557
# SVM的测试集结果：
# 65 186
# 准确率为0.817741935483871
# 正类召回率为0.6565656565656566
# 负类召回率为0.8942307692307693
# MCC为0.571306823879
# 0.817589576547
# SVM的测试集结果：
# 69 186
# 准确率为0.830215053763441
# 正类召回率为0.696969696969697
# 负类召回率为0.8942307692307693
# MCC为0.605112968878
# 0.830618892508
# SVM的测试集结果：
# 69 185
# 准确率为0.8273118279569893
# 正类召回率为0.696969696969697
# 负类召回率为0.8894230769230769
# MCC为0.59830789139
# 0.827361563518
# SVM的测试集结果：
# 62 186
# 准确率为0.808709677419355
# 正类召回率为0.6262626262626263
# 负类召回率为0.8942307692307693
# MCC为0.545723195349
# 0.807817589577
# SVM的测试集结果：
# 68 185
# 准确率为0.8236559139784946
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 0.824104234528
# SVM的测试集结果：
# 73 185
# 准确率为0.8403225806451612
# 正类召回率为0.7373737373737373
# 负类召回率为0.8894230769230769
# MCC为0.631973985065
# 0.840390879479
# SVM的测试集结果：
# 66 184
# 准确率为0.8143010752688171
# 正类召回率为0.6666666666666666
# 负类召回率为0.8846153846153846
# MCC为0.566072420238
# 0.814332247557
# SVM的测试集结果：
# 71 185
# 准确率为0.8339784946236559
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 0.833876221498
# SVM的测试集结果：
# 73 186
# 准确率为0.843978494623656
# 正类召回率为0.7373737373737373
# 负类召回率为0.8942307692307693
# MCC为0.638652698856
# 0.843648208469
# SVM的测试集结果：
# 69 185
# 准确率为0.8270967741935484
# 正类召回率为0.696969696969697
# 负类召回率为0.8894230769230769
# MCC为0.59830789139
# 0.827361563518
# SVM的测试集结果：
# 64 181
# 准确率为0.7984946236559141
# 正类召回率为0.6464646464646465
# 负类召回率为0.8701923076923077
# MCC为0.528815251839
# 0.798045602606
# SVM的测试集结果：
# 65 181
# 准确率为0.801290322580645
# 正类召回率为0.6565656565656566
# 负类召回率为0.8701923076923077
# MCC为0.537461341442
# 0.801302931596
# SVM的测试集结果：
# 68 182
# 准确率为0.8144086021505377
# 正类召回率为0.6868686868686869
# 负类召回率为0.875
# MCC为0.56981039222
# 0.814332247557
# SVM的测试集结果：
# 71 185
# 准确率为0.8341935483870968
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 0.833876221498
# SVM的测试集结果：
# 65 186
# 准确率为0.8175268817204302
# 正类召回率为0.6565656565656566
# 负类召回率为0.8942307692307693
# MCC为0.571306823879
# 0.817589576547
# SVM的测试集结果：
# 66 185
# 准确率为0.8173118279569893
# 正类召回率为0.6666666666666666
# 负类召回率为0.8894230769230769
# MCC为0.57288954914
# 0.817589576547
# SVM的测试集结果：
# 70 183
# 准确率为0.8245161290322581
# 正类召回率为0.7070707070707071
# 负类召回率为0.8798076923076923
# MCC为0.593427484675
# 0.824104234528
# SVM的测试集结果：
# 69 181
# 准确率为0.8150537634408602
# 正类召回率为0.696969696969697
# 负类召回率为0.8701923076923077
# MCC为0.571846608164
# 0.814332247557
# SVM的测试集结果：
# 67 184
# 准确率为0.817741935483871
# 正类召回率为0.6767676767676768
# 负类召回率为0.8846153846153846
# MCC为0.574593882062
# 0.817589576547
# SVM的测试集结果：
# 65 185
# 准确率为0.8140860215053763
# 正类召回率为0.6565656565656566
# 负类召回率为0.8894230769230769
# MCC为0.564377319301
# 0.814332247557
# SVM的测试集结果：
# 67 183
# 准确率为0.8144086021505377
# 正类召回率为0.6767676767676768
# 负类召回率为0.8798076923076923
# MCC为0.567884616416
# 0.814332247557
# SVM的测试集结果：
# 70 184
# 准确率为0.827204301075269
# 正类召回率为0.7070707070707071
# 负类召回率为0.8846153846153846
# MCC为0.600049249681
# 0.827361563518
# SVM的测试集结果：
# 66 185
# 准确率为0.8174193548387096
# 正类召回率为0.6666666666666666
# 负类召回率为0.8894230769230769
# MCC为0.57288954914
# 0.817589576547
# SVM的测试集结果：
# 66 183
# 准确率为0.8112903225806454
# 正类召回率为0.6666666666666666
# 负类召回率为0.8798076923076923
# MCC为0.559334338655
# 0.811074918567
# SVM的测试集结果：
# 65 185
# 准确率为0.8146236559139786
# 正类召回率为0.6565656565656566
# 负类召回率为0.8894230769230769
# MCC为0.564377319301
# 0.814332247557
# SVM的测试集结果：
# 70 185
# 准确率为0.8307526881720431
# 正类召回率为0.7070707070707071
# 负类召回率为0.8894230769230769
# MCC为0.606745866171
# 0.830618892508
# SVM的测试集结果：
# 71 186
# 准确率为0.8375268817204301
# 正类召回率为0.7171717171717171
# 负类召回率为0.8942307692307693
# MCC为0.621910808035
# 0.837133550489
# SVM的测试集结果：
# 72 187
# 准确率为0.8439784946236559
# 正类召回率为0.7272727272727273
# 负类召回率为0.8990384615384616
# MCC为0.637075749899
# 0.843648208469
# SVM的测试集结果：
# 64 186
# 准确率为0.8141935483870968
# 正类召回率为0.6464646464646465
# 负类召回率为0.8942307692307693
# MCC为0.562803240995
# 0.814332247557
# SVM的测试集结果：
# 66 183
# 准确率为0.8113978494623657
# 正类召回率为0.6666666666666666
# 负类召回率为0.8798076923076923
# MCC为0.559334338655
# 0.811074918567
# SVM的测试集结果：
# 67 188
# 准确率为0.8303225806451614
# 正类召回率为0.6767676767676768
# 负类召回率为0.9038461538461539
# MCC为0.602234560597
# 0.830618892508
# SVM的测试集结果：
# 68 185
# 准确率为0.8239784946236559
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 0.824104234528
# SVM的测试集结果：
# 66 186
# 准确率为0.8209677419354838
# 正类召回率为0.6666666666666666
# 负类召回率为0.8942307692307693
# MCC为0.579788138213
# 0.820846905537
# SVM的测试集结果：
# 64 186
# 准确率为0.8145161290322582
# 正类召回率为0.6464646464646465
# 负类召回率为0.8942307692307693
# MCC为0.562803240995
# 0.814332247557
# SVM的测试集结果：
# 71 185
# 准确率为0.833763440860215
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 0.833876221498
# SVM的测试集结果：
# 63 187
# 准确率为0.8143010752688171
# 正类召回率为0.6363636363636364
# 负类召回率为0.8990384615384616
# MCC为0.561354565098
# 0.814332247557
# SVM的测试集结果：
# 67 185
# 准确率为0.8210752688172043
# 正类召回率为0.6767676767676768
# 负类召回率为0.8894230769230769
# MCC为0.58138110884
# 0.820846905537
# SVM的测试集结果：
# 67 186
# 准确率为0.8238709677419356
# 正类召回率为0.6767676767676768
# 负类召回率为0.8942307692307693
# MCC为0.588248652414
# 0.824104234528
# SVM的测试集结果：
# 68 184
# 准确率为0.8204301075268818
# 正类召回率为0.6868686868686869
# 负类召回率为0.8846153846153846
# MCC为0.583096253903
# 0.820846905537
# SVM的测试集结果：
# 66 187
# 准确率为0.8240860215053762
# 正类召回率为0.6666666666666666
# 负类召回率为0.8990384615384616
# MCC为0.586770692238
# 0.824104234528
# SVM的测试集结果：
# 72 186
# 准确率为0.8402150537634409
# 正类召回率为0.7272727272727273
# 负类召回率为0.8942307692307693
# MCC为0.630288107142
# 0.840390879479
# SVM的测试集结果：
# 65 187
# 准确率为0.8207526881720429
# 正类召回率为0.6565656565656566
# 负类召回率为0.8990384615384616
# MCC为0.578321526875
# 0.820846905537
# SVM的测试集结果：
# 65 186
# 准确率为0.8178494623655915
# 正类召回率为0.6565656565656566
# 负类召回率为0.8942307692307693
# MCC为0.571306823879
# 0.817589576547
# SVM的测试集结果：
# 69 184
# 准确率为0.8240860215053762
# 正类召回率为0.696969696969697
# 负类召回率为0.8846153846153846
# MCC为0.591580924307
# 0.824104234528
# SVM的测试集结果：
# 69 185
# 准确率为0.8273118279569893
# 正类召回率为0.696969696969697
# 负类召回率为0.8894230769230769
# MCC为0.59830789139
# 0.827361563518
# SVM的测试集结果：
# 70 185
# 准确率为0.8305376344086023
# 正类召回率为0.7070707070707071
# 负类召回率为0.8894230769230769
# MCC为0.606745866171
# 0.830618892508
# SVM的测试集结果：
# 67 186
# 准确率为0.8240860215053762
# 正类召回率为0.6767676767676768
# 负类召回率为0.8942307692307693
# MCC为0.588248652414
# 0.824104234528
# SVM的测试集结果：
# 64 185
# 准确率为0.8113978494623657
# 正类召回率为0.6464646464646465
# 负类召回率为0.8894230769230769
# MCC为0.55584295552
# 0.811074918567
# SVM的测试集结果：
# 66 184
# 准确率为0.8140860215053763
# 正类召回率为0.6666666666666666
# 负类召回率为0.8846153846153846
# MCC为0.566072420238
# 0.814332247557
# SVM的测试集结果：
# 64 185
# 准确率为0.810752688172043
# 正类召回率为0.6464646464646465
# 负类召回率为0.8894230769230769
# MCC为0.55584295552
# 0.811074918567
# SVM的测试集结果：
# 69 184
# 准确率为0.8243010752688171
# 正类召回率为0.696969696969697
# 负类召回率为0.8846153846153846
# MCC为0.591580924307
# 0.824104234528
# SVM的测试集结果：
# 60 184
# 准确率为0.7946236559139785
# 正类召回率为0.6060606060606061
# 负类召回率为0.8846153846153846
# MCC为0.51446045585
# 0.794788273616
# SVM的测试集结果：
# 69 186
# 准确率为0.8310752688172045
# 正类召回率为0.696969696969697
# 负类召回率为0.8942307692307693
# MCC为0.605112968878
# 0.830618892508
# SVM的测试集结果：
# 70 182
# 准确率为0.8206451612903226
# 正类召回率为0.7070707070707071
# 负类召回率为0.875
# MCC为0.586878452389
# 0.820846905537
# SVM的测试集结果：
# 70 186
# 准确率为0.833763440860215
# 正类召回率为0.7070707070707071
# 负类召回率为0.8942307692307693
# MCC为0.613519528877
# 0.833876221498
# SVM的测试集结果：
# 70 185
# 准确率为0.8306451612903226
# 正类召回率为0.7070707070707071
# 负类召回率为0.8894230769230769
# MCC为0.606745866171
# 0.830618892508
# SVM的测试集结果：
# 69 185
# 准确率为0.827204301075269
# 正类召回率为0.696969696969697
# 负类召回率为0.8894230769230769
# MCC为0.59830789139
# 0.827361563518
# SVM的测试集结果：
# 71 185
# 准确率为0.8339784946236559
# 正类召回率为0.7171717171717171
# 负类召回率为0.8894230769230769
# MCC为0.615168678412
# 0.833876221498
# SVM的测试集结果：
# 72 185
# 准确率为0.8368817204301076
# 正类召回率为0.7272727272727273
# 负类召回率为0.8894230769230769
# MCC为0.623577627463
# 0.837133550489
# SVM的测试集结果：
# 67 185
# 准确率为0.8211827956989248
# 正类召回率为0.6767676767676768
# 负类召回率为0.8894230769230769
# MCC为0.58138110884
# 0.820846905537
# SVM的测试集结果：
# 63 188
# 准确率为0.8170967741935484
# 正类召回率为0.6363636363636364
# 负类召回率为0.9038461538461539
# MCC为0.568523812918
# 0.817589576547
# SVM的测试集结果：
# 66 187
# 准确率为0.8239784946236559
# 正类召回率为0.6666666666666666
# 负类召回率为0.8990384615384616
# MCC为0.586770692238
# 0.824104234528
# SVM的测试集结果：
# 72 185
# 准确率为0.836774193548387
# 正类召回率为0.7272727272727273
# 负类召回率为0.8894230769230769
# MCC为0.623577627463
# 0.837133550489
# SVM的测试集结果：
# 69 184
# 准确率为0.8240860215053765
# 正类召回率为0.696969696969697
# 负类召回率为0.8846153846153846
# MCC为0.591580924307
# 0.824104234528
# SVM的测试集结果：
# 68 186
# 准确率为0.8273118279569893
# 正类召回率为0.6868686868686869
# 负类召回率为0.8942307692307693
# MCC为0.596689797443
# 0.827361563518
# SVM的测试集结果：
# 67 186
# 准确率为0.8245161290322581
# 正类召回率为0.6767676767676768
# 负类召回率为0.8942307692307693
# MCC为0.588248652414
# 0.824104234528
# SVM的测试集结果：
# 68 189
# 准确率为0.8364516129032259
# 正类召回率为0.6868686868686869
# 负类召回率为0.9086538461538461
# MCC为0.617698428957
# 0.837133550489
# SVM的测试集结果：
# 70 187
# 准确率为0.8370967741935484
# 正类召回率为0.7070707070707071
# 负类召回率为0.8990384615384616
# MCC为0.620372512285
# 0.837133550489
# SVM的测试集结果：
# 67 187
# 准确率为0.827741935483871
# 正类召回率为0.6767676767676768
# 负类召回率为0.8990384615384616
# MCC为0.595198957125
# 0.827361563518
# SVM的测试集结果：
# 68 187
# 准确率为0.8303225806451614
# 正类召回率为0.6868686868686869
# 负类召回率为0.8990384615384616
# MCC为0.603607755688
# 0.830618892508
# SVM的测试集结果：
# 68 187
# 准确率为0.8305376344086021
# 正类召回率为0.6868686868686869
# 负类召回率为0.8990384615384616
# MCC为0.603607755688
# 0.830618892508
# SVM的测试集结果：
# 69 185
# 准确率为0.827741935483871
# 正类召回率为0.696969696969697
# 负类召回率为0.8894230769230769
# MCC为0.59830789139
# 0.827361563518
# SVM的测试集结果：
# 72 188
# 准确率为0.8469892473118279
# 正类召回率为0.7272727272727273
# 负类召回率为0.9038461538461539
# MCC为0.643942803851
# 0.846905537459
# SVM的测试集结果：
# 65 186
# 准确率为0.818279569892473
# 正类召回率为0.6565656565656566
# 负类召回率为0.8942307692307693
# MCC为0.571306823879
# 0.817589576547
# SVM的测试集结果：
# 66 185
# 准确率为0.816989247311828
# 正类召回率为0.6666666666666666
# 负类召回率为0.8894230769230769
# MCC为0.57288954914
# 0.817589576547
# SVM的测试集结果：
# 72 187
# 准确率为0.8435483870967742
# 正类召回率为0.7272727272727273
# 负类召回率为0.8990384615384616
# MCC为0.637075749899
# 0.843648208469
# SVM的测试集结果：
# 64 184
# 准确率为0.8080645161290322
# 正类召回率为0.6464646464646465
# 负类召回率为0.8846153846153846
# MCC为0.548966500389
# 0.807817589577
# SVM的测试集结果：
# 72 183
# 准确率为0.8305376344086021
# 正类召回率为0.7272727272727273
# 负类召回率为0.8798076923076923
# MCC为0.610379551683
# 0.830618892508
# SVM的测试集结果：
# 70 184
# 准确率为0.8278494623655914
# 正类召回率为0.7070707070707071
# 负类召回率为0.8846153846153846
# MCC为0.600049249681
# 0.827361563518
# SVM的测试集结果：
# 68 185
# 准确率为0.8234408602150538
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 0.824104234528
# SVM的测试集结果：
# 67 184
# 准确率为0.8178494623655915
# 正类召回率为0.6767676767676768
# 负类召回率为0.8846153846153846
# MCC为0.574593882062
# 0.817589576547
# SVM的测试集结果：
# 67 185
# 准确率为0.8207526881720429
# 正类召回率为0.6767676767676768
# 负类召回率为0.8894230769230769
# MCC为0.58138110884
# 0.820846905537
# SVM的测试集结果：
# 70 186
# 准确率为0.8336559139784946
# 正类召回率为0.7070707070707071
# 负类召回率为0.8942307692307693
# MCC为0.613519528877
# 0.833876221498
# SVM的测试集结果：
# 68 182
# 准确率为0.8141935483870967
# 正类召回率为0.6868686868686869
# 负类召回率为0.875
# MCC为0.56981039222
# 0.814332247557
# SVM的测试集结果：
# 70 187
# 准确率为0.8374193548387098
# 正类召回率为0.7070707070707071
# 负类召回率为0.8990384615384616
# MCC为0.620372512285
# 0.837133550489
# SVM的测试集结果：
# 68 183
# 准确率为0.817741935483871
# 正类召回率为0.6868686868686869
# 负类召回率为0.8798076923076923
# MCC为0.576415982443
# 0.817589576547
# SVM的测试集结果：
# 68 185
# 准确率为0.824516129032258
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 0.824104234528
# SVM的测试集结果：
# 65 182
# 准确率为0.803763440860215
# 正类召回率为0.6565656565656566
# 负类召回率为0.875
# MCC为0.544074795247
# 0.804560260586
# SVM的测试集结果：
# 64 184
# 准确率为0.8082795698924731
# 正类召回率为0.6464646464646465
# 负类召回率为0.8846153846153846
# MCC为0.548966500389
# 0.807817589577
# SVM的测试集结果：
# 69 187
# 准确率为0.8336559139784946
# 正类召回率为0.696969696969697
# 负类召回率为0.8990384615384616
# MCC为0.611998486045
# 0.833876221498
# SVM的测试集结果：
# 68 185
# 准确率为0.8236559139784946
# 正类召回率为0.6868686868686869
# 负类召回率为0.8894230769230769
# MCC为0.58985342547
# 0.824104234528
# SVM的测试集结果：
# 65 184
# 准确率为0.8108602150537635
# 正类召回率为0.6565656565656566
# 负类召回率为0.8846153846153846
# MCC为0.557530445867
# 0.811074918567
# SVM的测试集结果：
# 68 181
# 准确率为0.8108602150537635
# 正类召回率为0.6868686868686869
# 负类召回率为0.8701923076923077
# MCC为0.563277341887
# 0.811074918567
# SVM的测试集结果：
# 68 186
# 准确率为0.8273118279569893
# 正类召回率为0.6868686868686869
# 负类召回率为0.8942307692307693
# MCC为0.596689797443
# 0.827361563518
# SVM的测试集结果：
# 73 183
# 准确率为0.8341935483870969
# 正类召回率为0.7373737373737373
# 负类召回率为0.8798076923076923
# MCC为0.618836518278
# 0.833876221498
# SVM的测试集结果：
# 68 183
# 准确率为0.8176344086021506
# 正类召回率为0.6868686868686869
# 负类召回率为0.8798076923076923
# MCC为0.576415982443
# 0.817589576547
# SVM的测试集结果：
# 67 184
# 准确率为0.8181720430107526
# 正类召回率为0.6767676767676768
# 负类召回率为0.8846153846153846
# MCC为0.574593882062
# 0.817589576547
# SVM的测试集结果：
# 67 188
# 准确率为0.8307526881720431
# 正类召回率为0.6767676767676768
# 负类召回率为0.9038461538461539
# MCC为0.602234560597
# 0.830618892508
# SVM的测试集结果：
# 64 185
# 准确率为0.8112903225806452
# 正类召回率为0.6464646464646465
# 负类召回率为0.8894230769230769
# MCC为0.55584295552
# 0.811074918567
# SVM的测试集结果：
# 67 186
# 准确率为0.8235483870967742
# 正类召回率为0.6767676767676768
# 负类召回率为0.8942307692307693
# MCC为0.588248652414
# 0.824104234528
# SVM的测试集结果：
# 68 186
# 准确率为0.8274193548387098
# 正类召回率为0.6868686868686869
# 负类召回率为0.8942307692307693
# MCC为0.596689797443
# 0.827361563518
# SVM的测试集结果：
# 70 185
# 准确率为0.8304301075268817
# 正类召回率为0.7070707070707071
# 负类召回率为0.8894230769230769
# MCC为0.606745866171
# 0.830618892508
# SVM的测试集结果：
# 67 187
# 准确率为0.8276344086021504
# 正类召回率为0.6767676767676768
# 负类召回率为0.8990384615384616
# MCC为0.595198957125
# 0.827361563518
# SVM的测试集结果：
# 67 186
# 准确率为0.8241935483870968
# 正类召回率为0.6767676767676768
# 负类召回率为0.8942307692307693
# MCC为0.588248652414
# 0.824104234528
# SVM的测试集结果：
# 67 189
# 准确率为0.8336559139784946
# 正类召回率为0.6767676767676768
# 负类召回率为0.9086538461538461
# MCC为0.609358098635
# 0.833876221498

# %%
print(acc)
print(pr)
print(nr)
print(MCC)
a = np.array(MCC)

np.savetxt('./2informationgain/MCC.csv',a, delimiter = ',')
# Out:
# [0.8341935483870969, 0.8336559139784946, 0.8305376344086021, 0.8404301075268817, 0.8082795698924732, 0.8239784946236559, 0.833763440860215, 0.8243010752688174, 0.8344086021505376, 0.8275268817204303, 0.8206451612903226, 0.8369892473118279, 0.8238709677419356, 0.8393548387096775, 0.8108602150537635, 0.8373118279569892, 0.797741935483871, 0.8206451612903226, 0.8367741935483872, 0.8208602150537635, 0.8300000000000001, 0.8275268817204301, 0.8241935483870968, 0.8304301075268817, 0.8274193548387098, 0.8170967741935484, 0.8306451612903226, 0.8241935483870968, 0.8208602150537635, 0.8178494623655913, 0.8311827956989248, 0.8178494623655915, 0.8275268817204301, 0.8110752688172044, 0.8208602150537635, 0.7945161290322581, 0.8434408602150537, 0.8281720430107526, 0.8181720430107526, 0.8206451612903226, 0.8244086021505377, 0.8112903225806452, 0.8241935483870968, 0.8308602150537636, 0.8213978494623657, 0.8274193548387098, 0.8207526881720429, 0.8208602150537635, 0.8178494623655913, 0.8208602150537635, 0.8203225806451613, 0.8306451612903226, 0.8172043010752688, 0.830752688172043, 0.8210752688172043, 0.8110752688172044, 0.8209677419354838, 0.8212903225806452, 0.8241935483870968, 0.8175268817204302, 0.8208602150537635, 0.8276344086021507, 0.8176344086021505, 0.8238709677419355, 0.833763440860215, 0.8341935483870968, 0.8046236559139786, 0.8336559139784946, 0.8208602150537635, 0.817741935483871, 0.8370967741935484, 0.8147311827956989, 0.8435483870967742, 0.8178494623655913, 0.8278494623655914, 0.8372043010752688, 0.8140860215053763, 0.8343010752688172, 0.8239784946236559, 0.8208602150537635, 0.8204301075268818, 0.8140860215053763, 0.8075268817204302, 0.8172043010752688, 0.8204301075268818, 0.8305376344086023, 0.8078494623655914, 0.8244086021505377, 0.8211827956989248, 0.8404301075268817, 0.8205376344086023, 0.8273118279569893, 0.830215053763441, 0.8270967741935484, 0.8141935483870968, 0.817741935483871, 0.830215053763441, 0.8273118279569893, 0.808709677419355, 0.8236559139784946, 0.8403225806451612, 0.8143010752688171, 0.8339784946236559, 0.843978494623656, 0.8270967741935484, 0.7984946236559141, 0.801290322580645, 0.8144086021505377, 0.8341935483870968, 0.8175268817204302, 0.8173118279569893, 0.8245161290322581, 0.8150537634408602, 0.817741935483871, 0.8140860215053763, 0.8144086021505377, 0.827204301075269, 0.8174193548387096, 0.8112903225806454, 0.8146236559139786, 0.8307526881720431, 0.8375268817204301, 0.8439784946236559, 0.8141935483870968, 0.8113978494623657, 0.8303225806451614, 0.8239784946236559, 0.8209677419354838, 0.8145161290322582, 0.833763440860215, 0.8143010752688171, 0.8210752688172043, 0.8238709677419356, 0.8204301075268818, 0.8240860215053762, 0.8402150537634409, 0.8207526881720429, 0.8178494623655915, 0.8240860215053762, 0.8273118279569893, 0.8305376344086023, 0.8240860215053762, 0.8113978494623657, 0.8140860215053763, 0.810752688172043, 0.8243010752688171, 0.7946236559139785, 0.8310752688172045, 0.8206451612903226, 0.833763440860215, 0.8306451612903226, 0.827204301075269, 0.8339784946236559, 0.8368817204301076, 0.8211827956989248, 0.8170967741935484, 0.8239784946236559, 0.836774193548387, 0.8240860215053765, 0.8273118279569893, 0.8245161290322581, 0.8364516129032259, 0.8370967741935484, 0.827741935483871, 0.8303225806451614, 0.8305376344086021, 0.827741935483871, 0.8469892473118279, 0.818279569892473, 0.816989247311828, 0.8435483870967742, 0.8080645161290322, 0.8305376344086021, 0.8278494623655914, 0.8234408602150538, 0.8178494623655915, 0.8207526881720429, 0.8336559139784946, 0.8141935483870967, 0.8374193548387098, 0.817741935483871, 0.824516129032258, 0.803763440860215, 0.8082795698924731, 0.8336559139784946, 0.8236559139784946, 0.8108602150537635, 0.8108602150537635, 0.8273118279569893, 0.8341935483870969, 0.8176344086021506, 0.8181720430107526, 0.8307526881720431, 0.8112903225806452, 0.8235483870967742, 0.8274193548387098, 0.8304301075268817, 0.8276344086021504, 0.8241935483870968, 0.8336559139784946]
# [0.7070707070707071, 0.696969696969697, 0.6868686868686869, 0.7070707070707071, 0.6363636363636364, 0.6868686868686869, 0.7373737373737373, 0.6868686868686869, 0.7171717171717171, 0.6868686868686869, 0.696969696969697, 0.7171717171717171, 0.6666666666666666, 0.7474747474747475, 0.6565656565656566, 0.7070707070707071, 0.6262626262626263, 0.6666666666666666, 0.7070707070707071, 0.6868686868686869, 0.7070707070707071, 0.696969696969697, 0.6868686868686869, 0.7070707070707071, 0.6868686868686869, 0.6666666666666666, 0.6868686868686869, 0.6868686868686869, 0.6565656565656566, 0.696969696969697, 0.696969696969697, 0.6868686868686869, 0.6767676767676768, 0.696969696969697, 0.6565656565656566, 0.6464646464646465, 0.7575757575757576, 0.6868686868686869, 0.6464646464646465, 0.6767676767676768, 0.6767676767676768, 0.6464646464646465, 0.6767676767676768, 0.6767676767676768, 0.6767676767676768, 0.6767676767676768, 0.6767676767676768, 0.6666666666666666, 0.6767676767676768, 0.7171717171717171, 0.6666666666666666, 0.7070707070707071, 0.6767676767676768, 0.7070707070707071, 0.6666666666666666, 0.6565656565656566, 0.6767676767676768, 0.6464646464646465, 0.6666666666666666, 0.6666666666666666, 0.6666666666666666, 0.696969696969697, 0.6868686868686869, 0.6666666666666666, 0.7272727272727273, 0.7272727272727273, 0.6363636363636364, 0.6868686868686869, 0.6565656565656566, 0.6666666666666666, 0.7171717171717171, 0.6565656565656566, 0.7272727272727273, 0.6868686868686869, 0.696969696969697, 0.7272727272727273, 0.6565656565656566, 0.7070707070707071, 0.6868686868686869, 0.6666666666666666, 0.6666666666666666, 0.6767676767676768, 0.6666666666666666, 0.6666666666666666, 0.696969696969697, 0.6868686868686869, 0.6666666666666666, 0.6767676767676768, 0.6666666666666666, 0.7474747474747475, 0.6666666666666666, 0.7070707070707071, 0.7171717171717171, 0.7070707070707071, 0.6666666666666666, 0.6565656565656566, 0.696969696969697, 0.696969696969697, 0.6262626262626263, 0.6868686868686869, 0.7373737373737373, 0.6666666666666666, 0.7171717171717171, 0.7373737373737373, 0.696969696969697, 0.6464646464646465, 0.6565656565656566, 0.6868686868686869, 0.7171717171717171, 0.6565656565656566, 0.6666666666666666, 0.7070707070707071, 0.696969696969697, 0.6767676767676768, 0.6565656565656566, 0.6767676767676768, 0.7070707070707071, 0.6666666666666666, 0.6666666666666666, 0.6565656565656566, 0.7070707070707071, 0.7171717171717171, 0.7272727272727273, 0.6464646464646465, 0.6666666666666666, 0.6767676767676768, 0.6868686868686869, 0.6666666666666666, 0.6464646464646465, 0.7171717171717171, 0.6363636363636364, 0.6767676767676768, 0.6767676767676768, 0.6868686868686869, 0.6666666666666666, 0.7272727272727273, 0.6565656565656566, 0.6565656565656566, 0.696969696969697, 0.696969696969697, 0.7070707070707071, 0.6767676767676768, 0.6464646464646465, 0.6666666666666666, 0.6464646464646465, 0.696969696969697, 0.6060606060606061, 0.696969696969697, 0.7070707070707071, 0.7070707070707071, 0.7070707070707071, 0.696969696969697, 0.7171717171717171, 0.7272727272727273, 0.6767676767676768, 0.6363636363636364, 0.6666666666666666, 0.7272727272727273, 0.696969696969697, 0.6868686868686869, 0.6767676767676768, 0.6868686868686869, 0.7070707070707071, 0.6767676767676768, 0.6868686868686869, 0.6868686868686869, 0.696969696969697, 0.7272727272727273, 0.6565656565656566, 0.6666666666666666, 0.7272727272727273, 0.6464646464646465, 0.7272727272727273, 0.7070707070707071, 0.6868686868686869, 0.6767676767676768, 0.6767676767676768, 0.7070707070707071, 0.6868686868686869, 0.7070707070707071, 0.6868686868686869, 0.6868686868686869, 0.6565656565656566, 0.6464646464646465, 0.696969696969697, 0.6868686868686869, 0.6565656565656566, 0.6868686868686869, 0.6868686868686869, 0.7373737373737373, 0.6868686868686869, 0.6767676767676768, 0.6767676767676768, 0.6464646464646465, 0.6767676767676768, 0.6868686868686869, 0.7070707070707071, 0.6767676767676768, 0.6767676767676768, 0.6767676767676768]
# [0.8942307692307693, 0.8990384615384616, 0.8990384615384616, 0.9038461538461539, 0.8894230769230769, 0.8894230769230769, 0.8798076923076923, 0.8894230769230769, 0.8894230769230769, 0.8942307692307693, 0.8798076923076923, 0.8942307692307693, 0.8990384615384616, 0.8846153846153846, 0.8846153846153846, 0.8990384615384616, 0.8798076923076923, 0.8942307692307693, 0.8990384615384616, 0.8846153846153846, 0.8894230769230769, 0.8894230769230769, 0.8894230769230769, 0.8894230769230769, 0.8942307692307693, 0.8894230769230769, 0.8990384615384616, 0.8894230769230769, 0.8990384615384616, 0.875, 0.8942307692307693, 0.8798076923076923, 0.8990384615384616, 0.8653846153846154, 0.8990384615384616, 0.8653846153846154, 0.8846153846153846, 0.8942307692307693, 0.8990384615384616, 0.8894230769230769, 0.8942307692307693, 0.8894230769230769, 0.8942307692307693, 0.9038461538461539, 0.8894230769230769, 0.8990384615384616, 0.8894230769230769, 0.8942307692307693, 0.8846153846153846, 0.8701923076923077, 0.8942307692307693, 0.8894230769230769, 0.8846153846153846, 0.8894230769230769, 0.8942307692307693, 0.8846153846153846, 0.8894230769230769, 0.9038461538461539, 0.8990384615384616, 0.8894230769230769, 0.8942307692307693, 0.8894230769230769, 0.8798076923076923, 0.8990384615384616, 0.8846153846153846, 0.8846153846153846, 0.8846153846153846, 0.9038461538461539, 0.8990384615384616, 0.8894230769230769, 0.8942307692307693, 0.8894230769230769, 0.8990384615384616, 0.8798076923076923, 0.8894230769230769, 0.8894230769230769, 0.8894230769230769, 0.8942307692307693, 0.8894230769230769, 0.8942307692307693, 0.8942307692307693, 0.8798076923076923, 0.875, 0.8894230769230769, 0.8798076923076923, 0.8990384615384616, 0.875, 0.8942307692307693, 0.8942307692307693, 0.8846153846153846, 0.8942307692307693, 0.8846153846153846, 0.8846153846153846, 0.8846153846153846, 0.8846153846153846, 0.8942307692307693, 0.8942307692307693, 0.8894230769230769, 0.8942307692307693, 0.8894230769230769, 0.8894230769230769, 0.8846153846153846, 0.8894230769230769, 0.8942307692307693, 0.8894230769230769, 0.8701923076923077, 0.8701923076923077, 0.875, 0.8894230769230769, 0.8942307692307693, 0.8894230769230769, 0.8798076923076923, 0.8701923076923077, 0.8846153846153846, 0.8894230769230769, 0.8798076923076923, 0.8846153846153846, 0.8894230769230769, 0.8798076923076923, 0.8894230769230769, 0.8894230769230769, 0.8942307692307693, 0.8990384615384616, 0.8942307692307693, 0.8798076923076923, 0.9038461538461539, 0.8894230769230769, 0.8942307692307693, 0.8942307692307693, 0.8894230769230769, 0.8990384615384616, 0.8894230769230769, 0.8942307692307693, 0.8846153846153846, 0.8990384615384616, 0.8942307692307693, 0.8990384615384616, 0.8942307692307693, 0.8846153846153846, 0.8894230769230769, 0.8894230769230769, 0.8942307692307693, 0.8894230769230769, 0.8846153846153846, 0.8894230769230769, 0.8846153846153846, 0.8846153846153846, 0.8942307692307693, 0.875, 0.8942307692307693, 0.8894230769230769, 0.8894230769230769, 0.8894230769230769, 0.8894230769230769, 0.8894230769230769, 0.9038461538461539, 0.8990384615384616, 0.8894230769230769, 0.8846153846153846, 0.8942307692307693, 0.8942307692307693, 0.9086538461538461, 0.8990384615384616, 0.8990384615384616, 0.8990384615384616, 0.8990384615384616, 0.8894230769230769, 0.9038461538461539, 0.8942307692307693, 0.8894230769230769, 0.8990384615384616, 0.8846153846153846, 0.8798076923076923, 0.8846153846153846, 0.8894230769230769, 0.8846153846153846, 0.8894230769230769, 0.8942307692307693, 0.875, 0.8990384615384616, 0.8798076923076923, 0.8894230769230769, 0.875, 0.8846153846153846, 0.8990384615384616, 0.8894230769230769, 0.8846153846153846, 0.8701923076923077, 0.8942307692307693, 0.8798076923076923, 0.8798076923076923, 0.8846153846153846, 0.9038461538461539, 0.8894230769230769, 0.8942307692307693, 0.8942307692307693, 0.8894230769230769, 0.8990384615384616, 0.8942307692307693, 0.9086538461538461]
# [0.61351952887719441, 0.61199848604484253, 0.60360775568751868, 0.62730717464712116, 0.54728495511564179, 0.58985342547001351, 0.61883651827838271, 0.58985342547001363, 0.61516867841163292, 0.5966897974425639, 0.58492982095068158, 0.62191080803504628, 0.5867706922381799, 0.63378520118903359, 0.55753044586669775, 0.62037251228543355, 0.52491521880110503, 0.57978813821300645, 0.62037251228543355, 0.58309625390299002, 0.6067458661711258, 0.59830789139009222, 0.58985342547001363, 0.6067458661711258, 0.59668979744256367, 0.57288954914030454, 0.60360775568751879, 0.58985342547001351, 0.57832152687522465, 0.57835241328088183, 0.60511296887772348, 0.57641598244328474, 0.59519895712481541, 0.56541038384798781, 0.57832152687522465, 0.52224970395458159, 0.64219114219114215, 0.5966897974425639, 0.56984998872991155, 0.58138110884028493, 0.58824865241391178, 0.55584295551964247, 0.58824865241391178, 0.6022345605974484, 0.58138110884028493, 0.5951989571248153, 0.58138110884028504, 0.57978813821300657, 0.57459388206230366, 0.58893915245708073, 0.57978813821300657, 0.6067458661711258, 0.57459388206230366, 0.6067458661711258, 0.57978813821300657, 0.55753044586669764, 0.58138110884028493, 0.57698593484713601, 0.5867706922381799, 0.57288954914030465, 0.57978813821300657, 0.59830789139009222, 0.57641598244328474, 0.58677069223817979, 0.61694214083953725, 0.61694214083953736, 0.54037908716037375, 0.61060977603662436, 0.57832152687522453, 0.57288954914030477, 0.62191080803504628, 0.56437731930119772, 0.63707574989896687, 0.57641598244328474, 0.59830789139009222, 0.62357762746255041, 0.56437731930119772, 0.61351952887719441, 0.58985342547001363, 0.57978813821300657, 0.57978813821300645, 0.56788461641588805, 0.55267297892878586, 0.57288954914030465, 0.58492982095068158, 0.60360775568751868, 0.55267297892878586, 0.58824865241391167, 0.57978813821300645, 0.63378520118903381, 0.57978813821300657, 0.60004924968115725, 0.60850255606866077, 0.60004924968115725, 0.5660724202380063, 0.57130682387891119, 0.60511296887772359, 0.59830789139009222, 0.54572319534871205, 0.58985342547001363, 0.63197398506475455, 0.5660724202380063, 0.61516867841163292, 0.63865269885643994, 0.59830789139009222, 0.52881525183917377, 0.53746134144168367, 0.56981039222020591, 0.61516867841163292, 0.57130682387891107, 0.57288954914030477, 0.59342748467477124, 0.57184660816388533, 0.57459388206230366, 0.5643773193011975, 0.56788461641588805, 0.60004924968115725, 0.57288954914030465, 0.5593343386545937, 0.5643773193011975, 0.6067458661711258, 0.62191080803504628, 0.63707574989896687, 0.56280324099543311, 0.55933433865459359, 0.60223456059744862, 0.58985342547001351, 0.57978813821300657, 0.56280324099543311, 0.61516867841163292, 0.56135456509792403, 0.58138110884028504, 0.58824865241391167, 0.58309625390299002, 0.58677069223817979, 0.63028810714210859, 0.57832152687522453, 0.57130682387891107, 0.59158092430720532, 0.59830789139009222, 0.6067458661711258, 0.58824865241391155, 0.55584295551964247, 0.5660724202380063, 0.55584295551964247, 0.59158092430720532, 0.51446045585028799, 0.60511296887772359, 0.58687845238910274, 0.61351952887719441, 0.6067458661711258, 0.59830789139009211, 0.61516867841163292, 0.62357762746255041, 0.58138110884028504, 0.56852381291804122, 0.58677069223817979, 0.62357762746255041, 0.59158092430720532, 0.59668979744256367, 0.58824865241391155, 0.61769842895671745, 0.62037251228543355, 0.5951989571248153, 0.60360775568751857, 0.60360775568751868, 0.59830789139009222, 0.64394280385139868, 0.57130682387891107, 0.57288954914030477, 0.63707574989896687, 0.54896650038938866, 0.61037955168252989, 0.60004924968115725, 0.58985342547001351, 0.57459388206230366, 0.58138110884028515, 0.61351952887719441, 0.56981039222020591, 0.62037251228543355, 0.57641598244328474, 0.58985342547001363, 0.54407479524688374, 0.54896650038938866, 0.61199848604484253, 0.58985342547001363, 0.55753044586669764, 0.56327734188699219, 0.59668979744256367, 0.61883651827838271, 0.57641598244328474, 0.574593 ...
# 0.823673655914
# 0.00970947366092
# 0.684494949495
# 0.0259101738408
# 0.889903846154
# 0.00795814680637
# 0.588600653576
# 0.0239637705803
